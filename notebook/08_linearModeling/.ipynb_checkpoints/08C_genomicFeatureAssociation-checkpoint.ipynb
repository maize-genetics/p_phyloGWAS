# %%
# library(asreml)
# library(asremlPlus)
library(data.table)
library(tidyverse)
library(parallel)
library(qqman)
library(topGO)
library(pheatmap)
library(ggplot2)
library(ggridges)
library(ape)
library(ggtree)
library(geiger)
library(taxize)
library(xgboost)
library(PRROC)
library(Biostrings)
library(canprot)

# %%
#asreml.license.activate(acode = "GHFF-ABBA-EDFE-FCGC")

# %%
library(asreml)
library(asremlPlus)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:ggtree’:
#
#     expand
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
# Online License checked out Wed Oct  8 15:32:18 2025
# Loading ASReml-R version 4.2

# %%
detach("package:asreml")
detach("package:asremlPlus")

# %% [markdown]
# # data loading

# %%
metadata = read.delim("/workdir/sh2246/p_phyloGWAS/data/Poaceae_metadata_highErrorFiltered_2025.10.08.tsv",header = T)

rownames(metadata) = metadata$assemblyID

# %%
# metadata$compdup = metadata$complete + metadata$duplicated

# %%
phyloKMat <- read.table('/workdir/sh2246/p_phyloGWAS/output/phyloK_728Poaceae_astral_20250407.txt')
colnames(phyloKMat) <- rownames(phyloKMat)

# %%
envData = read.table("/workdir/sh2246/p_phyloGWAS/output/envData_707Poaceae_20250804.txt")

# %%
envDf = cbind(rownames(envData),envData)
colnames(envDf)[1] = "assemblyID"
envDf$assemblyID = as.factor(envDf$assemblyID)

# %%
# load tree
spTre = read.tree("/workdir/sh2246/p_phyloGWAS/output/PoaceaeTree_angiosperm353_astral_filtered_20250407.nwk")
spTre.rooted = root(spTre,"ASM1935983v1")
spTre.rooted$edge.length[is.na(spTre.rooted$edge.length)] = 0.1

# %%
commonID = Reduce("intersect",list(spTre.rooted$tip.label,rownames(envDf),metadata$assemblyID))
length(commonID)
# Out:
# [1] 687

# %% [markdown]
# # load 1C genome size and processing

# %%
genomeSize = read.csv("/workdir/sh2246/p_phyloGWAS/data/PoaceaeGenomeSizes_Kew_20240814.csv",header = T)

# %%
dim(genomeSize)
# Out:
# [1] 983   2

# %%
genomeSizeAvg = tapply(genomeSize$GenomeSize,genomeSize$Species,mean)

# %%
genomeSizeAvg = data.frame(species = names(genomeSizeAvg),kew1C = genomeSizeAvg)

# %%
metadataPlus = merge(metadata[commonID,],genomeSizeAvg,by.x = "correctSpecies",by.y = "species",all.x = T)

# %%
rownames(metadataPlus) = metadataPlus$assemblyID

# %%
dim(metadataPlus) 
sum(!is.na(metadataPlus$kew1C))# only 201... too few matches...
# Out:
# [1] 687  24
# [1] 191

# %%
# Michelle's LOCO GSE
locoGSE = read.delim("/workdir/sh2246/p_phyloGWAS/data/genome_size_LocoGSE.txt")
locoGSE$SampleName = gsub("merged","",locoGSE$SampleName)

# %%
colnames(locoGSE)[2] = "locoGSE1Cx"

# %%
sum(duplicated(locoGSE$SampleName))
# Out:
# [1] 34

# %%
locoGSE = locoGSE[-which(locoGSE$SampleName%in%locoGSE[which(duplicated(locoGSE$SampleName)),1])[1:34],]

# %%
metadataPlus = merge(metadataPlus,locoGSE,by.x = "assemblyID",by.y = "SampleName",all.x = T)

# %%
rownames(metadataPlus) = metadataPlus$assemblyID

# %%
metadataPlus[is.na(metadataPlus$kew1C)&is.na(metadataPlus$locoGSE1Cx),]
# Out:
#                                       assemblyID
# Ab-Traiperm_572-DRAFT-PanAnd-1.0      Ab-Traiperm_572-DRAFT-PanAnd-1.0
# Ac-Pasquet1232-DRAFT-PanAnd-1.0       Ac-Pasquet1232-DRAFT-PanAnd-1.0
# Aegilops_markgrafii                   Aegilops_markgrafii
# Aet_v5.0                              Aet_v5.0
# Alloteropsis_cimicina                 Alloteropsis_cimicina
# AN21TNTL0178                          AN21TNTL0178
# ASEM_AUS1_V1.0                        ASEM_AUS1_V1.0
# ASM1103853v1                          ASM1103853v1
# ASM1179987v1                          ASM1179987v1
# ASM160229v1                           ASM160229v1
# ASM160231v1                           ASM160231v1
# ASM163321v2                           ASM163321v2
# ASM1813568v1                          ASM1813568v1
# ASM1927943v1                          ASM1927943v1
# ASM2333362v1                          ASM2333362v1
# ASM2560326v1                          ASM2560326v1
# ...

# %%
# assembly stats
asmStat = read.table("/workdir/sh2246/p_phyloGWAS/data/assemblies_Stats.txt",header = T)

# %%
head(asmStat)
# Out:
#   file                                           format type num_seqs
# 1 data/assemblies/10wheat_assembly_jagger.fa.gz  FASTA  DNA  138393
# 2 data/assemblies/10wheat_assembly_lancer.fa.gz  FASTA  DNA  119569
# 3 data/assemblies/10wheat_assembly_stanley.fa.gz FASTA  DNA  104381
# 4 data/assemblies/A17.fa.gz                      FASTA  DNA   11072
# 5 data/assemblies/A42.fa.gz                      FASTA  DNA   14098
# 6 data/assemblies/AANG_UGA4.fa.gz                FASTA  DNA   85819
#   sum_len     min_len avg_len   max_len   Q1    Q2      Q3     sum_gap
# 1 14538313898  385     105050.9 855759449   711  1035.0   1508 0
# 2 14281318419 1000     119440.0 839470345  1216  1638.0   2708 0
# 3 14463524036  385     138564.7 856542542   812  1185.0   1655 0
# 4 14080097902  626    1271685.1 556619333 23116 36142.5  79965 0
# 5 14389271479 1005    1020660.5 561888103 23907 42093.5 117923 0
# 6  1535690757  500      17894.5 161452156   765  1403.0   9524 0
# ...

# %%
asmStat$assemblyID = gsub(".fa.gz","",limma::strsplit2(asmStat$file,"/")[,3])

# %%
metadataPlus = merge(metadataPlus,asmStat[,c(5,18:20)],by = "assemblyID",all.x = T)

# %%
head(metadataPlus)
# Out:
#   assemblyID                       correctSpecies        tracker_sample_name
# 1 10wheat_assembly_jagger          Triticum aestivum
# 2 10wheat_assembly_lancer          Triticum aestivum
# 3 10wheat_assembly_stanley         Triticum aestivum
# 4 A17                              Hordeum bulbosum
# 5 A42                              Hordeum bulbosum
# 6 Ab-Traiperm_572-DRAFT-PanAnd-1.0 Andropogon burmanicus
#   CorrectEcotype   lifeHistory
# 1 Jagger           annual
# 2 LongReach Lancer annual
# 3 CDC Stanley      annual
# 4                  perennial
# 5                  perennial
# 6 Traiperm_572     perennial
#   technology                                          source complete
# 1 Illumina HiSeq4000; HiSeq X Ten; Illumina HiSeq2500 NCBI   102
# 2 Illumina HiSeq4000; HiSeq X Ten; Illumina HiSeq2500 NCBI   100
# 3 Illumina HiSeq4000; HiSeq X Ten; Illumina HiSeq2500 NCBI   102
# 4 Illumina Novaseq 6000; PacBio Sequel II             NCBI    22
# ...

# %%
metadataPlus$asmGC = metadataPlus$GC...*metadataPlus$sum_len/(metadataPlus$sum_len-metadataPlus$sum_n)
metadataPlus$asmSize = (metadataPlus$sum_len-metadataPlus$sum_n)

# %%
hist(metadataPlus$asmSize/1e9,xlab = "assembly size (Gb)",main = "")
# Out:
# Plot with title “”

# %%
hist(metadataPlus$asmGC,xlab = "assembly GC%",main = "")
# Out:
# Plot with title “”

# %%
plot(log10(metadataPlus$kew1C*978),log10(metadataPlus$asmSize/1e6),asp = 1,
     xlab = "Kew1C (pg) * 978",ylab = "assembly size (Mb)",xaxt = 'n',yaxt='n',
     col = ifelse(grepl("pacbio",metadataPlus$technology,ignore.case = T),"red","blue"))
axis(1,at = seq(2.5,4.5,.5),labels = round(10^seq(2.5,4.5,.5),2))
axis(2,at = seq(2.5,4.5,.5),labels = round(10^seq(2.5,4.5,.5),2))
abline(a = 0, b = 1)
abline(a = log10(2), b = 1,col = "gold")
cor(metadataPlus$kew1C*.978,(metadataPlus$sum_len-metadataPlus$sum_n)/1e9,use = "complete",method = "spearman")
legend("topleft",legend = c("PacBio","others"),col = c("red","blue"),pch = 1,bty = 'n')
# Out:
# [1] 0.898107
# plot without title

# %%
plot(metadataPlus$locoGSE,(metadataPlus$asmSize)/1e6,asp = 1,ylim = c(0,1e4),
     xlab = "locoGSE-1Cx(Mb)",ylab = "assembly size (Mb)",
     col = ifelse(grepl("pacbio",metadataPlus$technology,ignore.case = T),"red","blue"))
abline(a = 0,b = 1)
abline(a = 0,b = 2,col = "gold")
abline(a = 0,b = 3,col = "orange")
abline(a = 0,b = 4,col = "red")
abline(a = 0,b = 5,col = "darkred")
abline(a = 0,b = 6,col = "orchid")
cor(metadataPlus$locoGSE,(metadataPlus$sum_len-metadataPlus$sum_n)/1e6,use = "complete")
# Out:
# [1] 0.5139006
# plot without title

# %%
plot(log10(metadataPlus$locoGSE),log10((metadataPlus$asmSize)/1e6),asp = 1,
     xlab = "locoGSE-1Cx(Mb)",ylab = "assembly size (Mb)",xaxt = 'n',yaxt = 'n',
     col = ifelse(grepl("pacbio",metadataPlus$technology,ignore.case = T),"red","blue"))
axis(1,at = seq(2.5,4.5,.5),labels = round(10^seq(2.5,4.5,.5),2))
axis(2,at = seq(2.5,4.5,.5),labels = round(10^seq(2.5,4.5,.5),2))
abline(a = 0,b = 1)
abline(a = log10(2),b = 1,col = "gold")
abline(a = log10(3),b = 1,col = "orange")
abline(a = log10(4),b = 1,col = "red")
abline(a = log10(5),b = 1,col = "darkred")
abline(a = log10(6),b = 1,col = "orchid")
cor(metadataPlus$locoGSE,(metadataPlus$asmSize)/1e6,use = "complete",method = "spearman")
# Out:
# [1] 0.3819406
# plot without title

# %% [markdown]
# # amino acid composition calculation

# %%
aaFasta = mclapply(list.files("/workdir/sh2246/p_phyloGWAS/output/aminoAcidPerTaxa/",pattern = "*.fa",full.names = T),function(x) readAAStringSet(x),mc.cores = 30)

aa.comp = mclapply(aaFasta,function(x){
    tmp = letterFrequency(x,letters = AA_STANDARD)
    return(colSums(tmp)/sum(tmp))
},mc.cores = 5)


aa.comp = Reduce("rbind",aa.comp)

rownames(aa.comp) = gsub(".fa","",list.files("/workdir/sh2246/p_phyloGWAS/output/aminoAcidPerTaxa/",pattern = "*.fa"))

aa.comp = aa.comp[commonID,]

dim(aa.comp)
# Out:
# [1] 687  20

# %%
data.table::fwrite(aa.comp,"/workdir/sh2246/p_phyloGWAS/output/poaceae_aaComposition_20251008.txt",sep = "\t",row.names = T,col.names = T)
# Out:
# x being coerced from class: matrix to data.table

# %%
aa.comp = read.table("/workdir/sh2246/p_phyloGWAS/output/poaceae_aaComposition_20251008.txt",row.names =1,header = T)

# %%
options(repr.plot.width=8, repr.plot.height=6)
boxplot(aa.comp)
# Out:
# plot without title

# %%
plot(apply(aa.comp,2,mean),xlab= "amino acid",ylab = "Proportion",xaxt = "n",pch = 19,col = "blue")
arrows(x0 = 1:20,x1 = 1:20, 
       y0 = apply(aa.comp,2,mean)-apply(aa.comp,2,sd), y1 = apply(aa.comp,2,mean)+apply(aa.comp,2,sd),
       angle = 90, code = 3,length = .1)
axis(1, at = 1:20,labels = colnames(aa.comp))
# Out:
# plot without title

# %%
sort(apply(aa.comp,2,sd)/apply(aa.comp,2,mean))
# Out:
#           L           S           F           Q           V           H
# 0.005026564 0.008588036 0.008636168 0.008943973 0.009008291 0.009244475
#           Y           G           P           T           D           M
# 0.009642555 0.011150318 0.011481388 0.011492262 0.013436934 0.015343007
#           E           K           N           R           I           A
# 0.015769533 0.017590458 0.018617240 0.018723067 0.018739854 0.020092306
#           W           C
# 0.024359976 0.027060170

# %%
range(apply(aa.comp,2,sd)/apply(aa.comp,2,mean))
# Out:
# [1] 0.005026564 0.027060170

# %%
options(repr.plot.width=6, repr.plot.height=6)
pheatmap::pheatmap(cor(aa.comp))
# Out:
# plot without title

# %% [markdown]
# ## PCA to reduce dimension

# %%
# #CLR transformation for rigor but doesn't really change much (PC1 r = 0.99)
# # PCA.aa.comp.clr = prcomp(compositions::clr(aa.comp))


# PCA.aa.comp = prcomp(aa.comp)

# options(repr.plot.width=18, repr.plot.height=6)
# # png("/workdir/sh2246/p_phyloGWAS/output/figure/Fig4_S1.png",width = 8.7*3,height = 8.7,units = "cm",res = 600,
# #     pointsize = 10)
# par(mfrow = c(1,3))
# plot(1:20,PCA.aa.comp$sdev^2/sum(PCA.aa.comp$sdev^2)*100,xlab = "aaPCs",ylab = "% Variance explained")
# sum((PCA.aa.comp$sdev^2/sum(PCA.aa.comp$sdev^2))[1:3])
# plot(PCA.aa.comp$x,col = scales::alpha(rainbow(25)[as.factor(metadata[commonID,]$tribe)],.75),
#      xlim = c(-.02,.02),ylim = c(-0.03,0.02),xlab = "PC1 (66.4%)",ylab = "PC2 (24.1%)")
# # legend("topright",legend = levels(as.factor(metadata[commonID,]$tribe)),col = rainbow(25)[1:19],pch = 1)
# arrows(x0 = 0,y0 = 0,x1 = PCA.aa.comp$rotation[,1]/40,y1 = PCA.aa.comp$rotation[,2]/40,length = .1,col = "blue")
# text(PCA.aa.comp$rotation[,1]/40*1.1,PCA.aa.comp$rotation[,2]/40*1.1,labels = rownames(PCA.aa.comp$rotation),col = "blue")
# axis(3,at = seq(-0.02,0.02,0.01),labels = seq(-0.02,0.02,0.01)*40,col = "blue")
# axis(4,at = seq(-0.02,0.02,0.01),labels = seq(-0.02,0.02,0.01)*40,col = "blue")

# plot(PCA.aa.comp$x[,2:3],col = scales::alpha(rainbow(25)[as.factor(metadata[commonID,]$tribe)],.75),
#      xlim = c(-.03,.03),ylim = c(-0.02,0.02),xlab = "PC2 (24.1%)",ylab = "PC3 (3.8%)")
# legend("topright",legend = levels(as.factor(metadata[commonID,]$tribe)),col = rainbow(25)[1:19],pch = 1)
# arrows(x0 = 0,y0 = 0,x1 = PCA.aa.comp$rotation[,2]/40,y1 = PCA.aa.comp$rotation[,3]/40,length = .1,col = "blue")
# text(PCA.aa.comp$rotation[,2]/40*1.1,PCA.aa.comp$rotation[,3]/40*1.1,labels = rownames(PCA.aa.comp$rotation),col = "blue")
# axis(3,at = seq(-0.02,0.02,0.01),labels = seq(-0.02,0.02,0.01)*40,col = "blue")
# axis(4,at = seq(-0.02,0.02,0.01),labels = seq(-0.02,0.02,0.01)*40,col = "blue")
# # dev.off()

# (PCA.aa.comp$sdev^2/sum(PCA.aa.comp$sdev^2))[1:3]

# pheatmap(cor(cbind(PCA.aa.comp$x[,1:3],aa.comp),method = "pearson"))
# sort(cor(cbind(PCA.aa.comp$x[,1:3],aa.comp),method = "pearson")[,1])
# sort(cor(cbind(PCA.aa.comp$x[,1:3],aa.comp),method = "pearson")[,2])
# sort(cor(cbind(PCA.aa.comp$x[,1:3],aa.comp),method = "pearson")[,3])

# plot(cor(cbind(PCA.aa.comp$x[,1],aa.comp),method = "pearson")[-1,1],PCA.aa.comp$rotation[,1],type = 'n')
# text(cor(cbind(PCA.aa.comp$x[,1],aa.comp),method = "pearson")[-1,1],PCA.aa.comp$rotation[,1],label = rownames(PCA.aa.comp$rotation))

# pheatmap(PCA.aa.comp$rotation[,1:3],cluster_cols = F,display_numbers = T)

# %% [markdown]
# # a.a. composition per OG

# %%
aaFastaPerOG = mclapply(list.files("/workdir/sh2246/p_phyloGWAS/output/orthofinderProteinMSAs_fullset_20250710/",pattern = "*.fa",
                                   full.names = T),function(x) readAAStringSet(x),mc.cores = 5)

names(aaFastaPerOG) = gsub(".fa","",list.files("/workdir/sh2246/p_phyloGWAS/output/orthofinderProteinMSAs_fullset_20250710/",pattern = "*.fa"))

aa.comp.og = mclapply(aaFastaPerOG,function(x){
    tmp = letterFrequency(x,letters = AA_STANDARD)
    rownames(tmp) = names(x)
    return(tmp)
},mc.cores = 5)

# %%
aa.comp.perOG = mclapply(aa.comp.og,function(x) {
    tmp = apply(x,2,function(a) tapply(a,limma::strsplit2(rownames(x),":")[,2],sum))
    return(as.data.frame(tmp)[commonID,])
    },mc.cores = 5)

aa.comp.perOG.array = simplify2array(lapply(aa.comp.perOG,as.matrix))

# %% [markdown]
# ### filter/subset based on protein abundance

# %%
FPKM = read.csv("/workdir/sh2246/p_phyloGWAS/data/maxFPKM_v5.csv")

# %%
mappingFile = read.table("/workdir/sh2246/p_phyloGWAS_archived/output/OGToZm_mapping_v2.txt")
colnames(mappingFile) = c("ZmID","OG")
mappingFile$ZmGeneID = substr(mappingFile$ZmID,1,15)

# %%
FPKMmerged = merge(FPKM,mappingFile,by.x = "Gene",by.y = "ZmGeneID",all.x = T)

# %%
table(is.na(FPKMmerged$OG))
# Out:
# FALSE  TRUE
# 20955 15670

# %%
with(FPKMmerged,boxplot(log2(maxFPKM+1)~is.na(OG)))
# Out:
# plot without title

# %%
# --- Colors (clustered by tissue; strong contrast across tissues) ---
series_cols <- c(
  # Reproductive (4) - magenta family
  "#CC79A7", "#A64D8A", "#E78AC3", "#8F3D8F",
  # Kernel (6) - sky/steel blue family
  "#56B4E9", "#2A7FB8", "#66CCFF", "#99DDFF", "#1F78B4", "#4C9ED9",
  # Shoot (2) - grayscale for max contrast
  "#000000", "#666666",
  # Leaf (5) - green/teal family
  "#009E73", "#007A59", "#33CC99", "#1B9E77", "#66E0B2",
  # Reproductive (1) - distinct magenta variant
  "#E7298A",
  # Root (5) - vermillion/orange family (no yellow)
  "#D55E00", "#A84400", "#FF751A", "#B94E00", "#803300"
)

# --- Line types (varied within each tissue cluster) ---
series_ltys <- c(
  # Reproductive (4)
  "solid", "dashed", "dotted", "dotdash",
  # Kernel (6)
  "solid", "dashed", "dotted", "dotdash", "longdash", "twodash",
  # Shoot (2)
  "solid", "dashed",
  # Leaf (5)
  "solid", "dashed", "dotted", "dotdash", "longdash",
  # Reproductive (1)
  "solid",
  # Root (5)
  "solid", "dashed", "dotted", "dotdash", "longdash"
)

# %%
options(repr.plot.width=8, repr.plot.height=8)
plot(cumsum(sort(FPKMmerged$Root...Cortex.5.Days,decreasing = T)),type ='n',
     xlab = "# of gene", ylab = "Cumulative protein abundance (FPKM)")
for (i in 23:45){
    lines(cumsum(sort(FPKMmerged[,i],decreasing = T)),
          col = series_cols[i-22],lty =series_ltys[i-22],lwd = 2)
}
# lines(cumsum(sort(FPKMmerged$maxFPKM,decreasing = T)),col = "red",lwd = 5,lty = 1)
legend("bottomright",legend = colnames(FPKMmerged)[23:45],
       col = series_cols,lty =series_ltys,seg.len = 3,
       bty = 'n',y.intersp = .6,lwd =2)
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height=8)
cutoffs = c()
topHundredPort = c()
plot(cumsum(sort(FPKMmerged$`Mature.Leaf.8`,decreasing = T))/sum(FPKMmerged$`Mature.Leaf.8`)*100,type ='n',
     xlab = "# of gene", ylab = "Cumulative protein abundance (%)")
for (i in 23:45){
    cumPort = cumsum(sort(FPKMmerged[,i],decreasing = T))/sum(FPKMmerged[,i])*100
    cutoffs = c(cutoffs,which(cumPort>50)[1])
    topHundredPort = c(topHundredPort,cumPort[100])
    lines(cumPort,col = series_cols[i-22],lty = series_ltys[i-22],lwd = 2)
}
# lines(cumsum(sort(FPKMmerged$maxFPKM,decreasing = T))/sum(FPKMmerged$maxFPKM)*100,col = "red",lwd = 5,lty = 1)
legend("bottomright",legend = colnames(FPKMmerged)[23:45],col = series_cols,lty = series_ltys,
       bty = 'n',y.intersp = .6,lwd =2,seg.len = 3)
# Out:
# plot without title

# %%
names(cutoffs) = colnames(FPKMmerged)[23:45]
cutoffs
# Out:
# Female.Spikelet.Collected.on.day.as.silk
#                                      773
#                                     Silk
#                                      616
#                    Ear.Primordium.2.4.mm
#                                     1807
#                    Ear.Primordium.6.8.mm
#                                     2075
#                         Endosperm.12.DAP
#                                      579
#                   Endosperm.Crown.27.DAP
#                                        8
#                 Pericarp.Aleurone.27.DAP
#                                       80
#                            Embryo.20.DAP
#                                     1193
#                            Embryo.38.DAP
#                                      291
#                 Germinatin.Kernels.2.DAI
#                                     1341
#                           X6.7.internode
#                                     1093
#                           X7.8.internode
# ...

# %%
highProt = list()
topProt = list()
for(i in 1:23){
    highProt[[i]] = which(rank(FPKMmerged[,i+22]) > (nrow(FPKMmerged) - cutoffs[i]))
    topProt[[i]] = which(rank(FPKMmerged[,i+22]) > (nrow(FPKMmerged) - 100))
}

# %%
names(highProt) = names(cutoffs)
names(topProt) = names(cutoffs)

# %%
options(repr.plot.width=8, repr.plot.height=6)
par(mar = c(18,5,1,1))
barplot(sort(sapply(highProt,length)),las = 2)
# Out:
# plot without title

# %%
names(topHundredPort) = names(cutoffs)

# %%
options(repr.plot.width=8, repr.plot.height=8)
par(mar = c(18,5,1,1))
barplot(sort(topHundredPort),las = 2,ylab = "% protein abundance by the top 100 abundant genes")
# Out:
# plot without title

# %%
length(unique(unlist(highProt)))
# Out:
# [1] 4279

# %%
abundantOG = na.omit(FPKMmerged[unique(unlist(highProt)),]$OG)
length(abundantOG)
abundantOGLeaf = na.omit(FPKMmerged[unique(unlist(highProt[grep("Leaf",names(highProt))])),]$OG)
length(abundantOGLeaf)
abundantOGRoot = na.omit(FPKMmerged[unique(unlist(highProt[grep("Root",names(highProt))])),]$OG)
length(abundantOGRoot)
# Out:
# [1] 2676
# [1] 1744
# [1] 590

# %%
length(intersect(abundantOGLeaf,abundantOGRoot))
length(setdiff(abundantOGLeaf,abundantOGRoot))
length(setdiff(abundantOGRoot,abundantOGLeaf))
# Out:
# [1] 384
# [1] 1330
# [1] 196

# %%
topOG = na.omit(FPKMmerged[unique(unlist(topProt)),]$OG)
length(topOG)
topOGLeaf = na.omit(FPKMmerged[unique(unlist(topProt[grep("Leaf",names(highProt))])),]$OG)
length(topOGLeaf)
topOGRoot = na.omit(FPKMmerged[unique(unlist(topProt[grep("Root",names(highProt))])),]$OG)
length(topOGRoot)
# Out:
# [1] 370
# [1] 115
# [1] 108

# %%
length(intersect(topOGLeaf,topOGRoot))
length(setdiff(topOGLeaf,topOGRoot))
length(setdiff(topOGRoot,topOGLeaf))
# Out:
# [1] 36
# [1] 79
# [1] 72

# %%
nrow(FPKMmerged)
# Out:
# [1] 36625

# %%
options(repr.plot.width=10, repr.plot.height=6)
barplot(table(table(unlist(highProt))))
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=6)
barplot(table(table(unlist(topProt))))
# Out:
# plot without title

# %%
aa.comp.others = apply(aa.comp.perOG.array[,,!dimnames(aa.comp.perOG.array)[[3]]%in%abundantOG],c(1,2),function(x) sum(x,na.rm = T))
aa.comp.others = aa.comp.others/rowSums(aa.comp.others)

# %%
aa.comp.abundant = apply(aa.comp.perOG.array[,,abundantOG],c(1,2),function(x) sum(x,na.rm = T))
aa.comp.abundant = aa.comp.abundant/rowSums(aa.comp.abundant)

# %%
aa.comp.abundantLeaf = apply(aa.comp.perOG.array[,,abundantOGLeaf],c(1,2),function(x) sum(x,na.rm = T))
aa.comp.abundantLeaf = aa.comp.abundantLeaf/rowSums(aa.comp.abundantLeaf)

# %%
aa.comp.abundantRoot = apply(aa.comp.perOG.array[,,abundantOGRoot],c(1,2),function(x) sum(x,na.rm = T))
aa.comp.abundantRoot = aa.comp.abundantRoot/rowSums(aa.comp.abundantRoot)

# %%
aa.comp.topLeaf = apply(aa.comp.perOG.array[,,topOGLeaf],c(1,2),function(x) sum(x,na.rm = T))
aa.comp.topLeaf = aa.comp.topLeaf/rowSums(aa.comp.topLeaf)

# %%
aa.comp.topRoot = apply(aa.comp.perOG.array[,,topOGRoot],c(1,2),function(x) sum(x,na.rm = T))
aa.comp.topRoot = aa.comp.topRoot/rowSums(aa.comp.topRoot)

# %%
aa.prop.perOG = array(apply(aa.comp.perOG.array,3,function(x) x/rowSums(x,na.rm = T)),dim = dim(aa.comp.perOG.array))

# %%
dim(aa.prop.perOG)
# Out:
# [1]   687    20 22196

# %%
dimnames(aa.prop.perOG) = dimnames(aa.comp.perOG.array)

# %%
options(repr.plot.width=6, repr.plot.height=6)
plot(apply(aa.comp.others,2,mean),apply(aa.comp.abundant,2,mean),xlab = "low-abundance OGs",ylab = "abundant OGs",type ='n')
abline(a = 0, b = 1,col = "blue",lty = 2)
text(apply(aa.comp.others,2,mean),apply(aa.comp.abundant,2,mean),labels = colnames(aa.comp.abundant),cex = 1.5)
# Out:
# plot without title

# %%
options(repr.plot.width=6, repr.plot.height=6)
plot(apply(aa.comp.abundantLeaf,2,mean),apply(aa.comp.abundantRoot,2,mean),xlab = "leaf abundant",ylab = "root abundant",type ='n')
abline(a = 0, b = 1,col = "blue",lty = 2)
text(apply(aa.comp.abundantLeaf,2,mean),apply(aa.comp.abundantRoot,2,mean),labels = colnames(aa.comp.abundant),cex = 1.5)
# Out:
# plot without title

# %%
options(repr.plot.width=6, repr.plot.height=6)
plot(apply(aa.comp.topLeaf,2,mean),apply(aa.comp.topRoot,2,mean),xlab = "leaf top 100",ylab = "root top 100",type ='n')
abline(a = 0, b = 1,col = "blue",lty = 2)
text(apply(aa.comp.topLeaf,2,mean),apply(aa.comp.topRoot,2,mean),labels = colnames(aa.comp.abundant),cex = 1.5)
# Out:
# plot without title

# %%
options(repr.plot.width=12, repr.plot.height=6)
par(mfrow = c(1,2))
plot(apply(aa.comp.others,2,mean),apply(aa.comp.abundantLeaf,2,mean),xlab = "low-abundance OG",ylab = "leaf abundant",type ='n')
abline(a = 0, b = 1,col = "blue",lty = 2)
text(apply(aa.comp.others,2,mean),apply(aa.comp.abundantLeaf,2,mean),labels = colnames(aa.comp.abundant),cex = 1.5)

plot(apply(aa.comp.others,2,mean),apply(aa.comp.abundantRoot,2,mean),xlab = "low-abundance OG",ylab = "root abundant",type ='n')
abline(a = 0, b = 1,col = "blue",lty = 2)
text(apply(aa.comp.others,2,mean),apply(aa.comp.abundantRoot,2,mean),labels = colnames(aa.comp.abundant),cex = 1.5)
# Out:
# plot without title

# %%
options(repr.plot.width=12, repr.plot.height=6)
par(mfrow = c(1,2))
plot(apply(aa.comp.others,2,mean),apply(aa.comp.topLeaf,2,mean),xlab = "low-abundance OG",ylab = "leaf top 100",type ='n')
abline(a = 0, b = 1,col = "blue",lty = 2)
text(apply(aa.comp.others,2,mean),apply(aa.comp.topLeaf,2,mean),labels = colnames(aa.comp.abundant),cex = 1.5)

plot(apply(aa.comp.others,2,mean),apply(aa.comp.topRoot,2,mean),xlab = "low-abundance OG",ylab = "root top 100",type ='n')
abline(a = 0, b = 1,col = "blue",lty = 2)
text(apply(aa.comp.others,2,mean),apply(aa.comp.topRoot,2,mean),labels = colnames(aa.comp.abundant),cex = 1.5)
# Out:
# plot without title

# %%
options(repr.plot.width=12, repr.plot.height=6)
boxplot((aa.comp.abundantLeaf-aa.comp.others),
        ylab = expression(paste(Delta,"Portion")),main = "leaf abundant vs. low-abundance")
abline(h=0,col = 'blue',lty = 2)
boxplot((aa.comp.abundantRoot-aa.comp.others),
        ylab = expression(paste(Delta,"Portion")),main = "root abundant vs. low-abundance")
abline(h=0,col = 'blue',lty = 2)
# Out:
# Plot with title “leaf abundant vs. low-abundance”
# Plot with title “root abundant vs. low-abundance”

# %%
options(repr.plot.width=12, repr.plot.height=6)
boxplot((aa.comp.topLeaf-aa.comp.others),
        ylab = expression(paste(Delta,"Portion")),main = "leaf top 100 vs. low-abundance")
abline(h=0,col = 'blue',lty = 2)
boxplot((aa.comp.topRoot-aa.comp.others),
        ylab = expression(paste(Delta,"Portion")),main = "root top 100 vs. low-abundance")
abline(h=0,col = 'blue',lty = 2)
# Out:
# Plot with title “leaf top 100 vs. low-abundance”
# Plot with title “root top 100 vs. low-abundance”

# %%
options(repr.plot.width=12, repr.plot.height=6)
par(mfrow = c(1,2))
LSD::heatscatter((aa.comp)[,"R"],(aa.comp)[,"K"],xlab = "R",ylab="K",main = "",asp = 1)
LSD::heatscatter((aa.comp.abundantLeaf)[,"R"],(aa.comp.abundantLeaf)[,"K"],xlab = "R",ylab="K",main = "",asp = 1)
# Out:
# Plot with title “”

# %%
options(repr.plot.width=6, repr.plot.height=6)
LSD::heatscatter((aa.comp)[,"R"],(aa.comp)[,"K"],xlab = "R",ylab="K",main = "",asp =1)
abline(a = median(aa.comp[,"R"]+aa.comp[,"K"]), b= -1)
# Out:
# Plot with title “”

# %%
LSD::heatscatter((aa.comp)[,"R"],(aa.comp)[,"K"]+(aa.comp)[,"E"],
                 xlab = "R",ylab="K+E",main = "",
                 asp =1)
abline(a = median(aa.comp[,"R"]+aa.comp[,"K"]+aa.comp[,"E"]), b= -1)
# Out:
# Plot with title “”

# %%
cor((aa.comp.abundantLeaf)[,"R"],(aa.comp.abundantLeaf)[,"K"],method = "spearman")
cor((aa.comp)[,"R"],(aa.comp)[,"K"],method = "spearman")
# Out:
# [1] -0.4128012
# [1] -0.7158265

# %%
options(repr.plot.width=6, repr.plot.height=6)
LSD::heatscatter((aa.comp.abundantLeaf-aa.comp.others)[,"R"],
                 (aa.comp.abundantLeaf-aa.comp.others)[,"K"],
                 xlab = expression(paste(Delta,"R")),ylab = expression(paste(Delta,"K")),main = "",asp = 1)
abline(a = 0, b= -1)
# Out:
# Plot with title “”

# %%
LSD::heatscatter(abs(aa.comp.abundantLeaf-aa.comp.others)[,"R"],abs(aa.comp.abundantLeaf-aa.comp.others)[,"K"],
                 xlab = expression(abs(paste(Delta,"R"))),ylab = expression(abs(paste(Delta,"K"))),main = "",
                 xlim = c(0.004,0.01), ylim = c(0.013,0.019))
# Out:
# Plot with title “”

# %%
cor((aa.comp.abundantLeaf-aa.comp.others)[,"R"],(aa.comp.abundantLeaf-aa.comp.others)[,"K"],method = "spearman")
# Out:
# [1] -0.499868

# %%
options(repr.plot.width=6, repr.plot.height=6)
plot(as.vector(cor(aa.comp.others)[upper.tri(cor(aa.comp.others))]),
     as.vector(cor(aa.comp.abundant)[upper.tri(cor(aa.comp))]),
     xlab = "low-abundance OGs",ylab = "abundant OGs",main = "correlation coefficients among a.a.")
cor(as.vector(cor(aa.comp.others)[upper.tri(cor(aa.comp))]),
    as.vector(cor(aa.comp.abundant)[upper.tri(cor(aa.comp))]),method = "spearman")
# Out:
# [1] 0.9499797
# Plot with title “correlation coefficients among a.a.”

# %%
options(repr.plot.width=12, repr.plot.height=6)
par(mfrow = c(1,2))
plot(as.vector(cor(aa.comp.others)[upper.tri(cor(aa.comp))]),as.vector(cor(aa.comp.abundantLeaf)[upper.tri(cor(aa.comp))]),
     xlab = "low abundance",ylab = "leaf abundant",main = "correlation coefficients among a.a.")
cor(as.vector(cor(aa.comp.abundantLeaf)[upper.tri(cor(aa.comp))]),as.vector(cor(aa.comp.others)[upper.tri(cor(aa.comp))]),method = "spearman")
plot(as.vector(cor(aa.comp.others)[upper.tri(cor(aa.comp))]),as.vector(cor(aa.comp.abundantRoot)[upper.tri(cor(aa.comp))]),
     xlab = "low abundance",ylab = "root abundant",main = "correlation coefficients among a.a.")
cor(as.vector(cor(aa.comp.abundantRoot)[upper.tri(cor(aa.comp))]),as.vector(cor(aa.comp.others)[upper.tri(cor(aa.comp))]),method = "spearman")
# Out:
# [1] 0.9043525
# [1] 0.6730517
# Plot with title “correlation coefficients among a.a.”

# %%
options(repr.plot.width=12, repr.plot.height=6)
par(mfrow = c(1,2))
plot(as.vector(cor(aa.comp.others)[upper.tri(cor(aa.comp))]),as.vector(cor(aa.comp.topLeaf)[upper.tri(cor(aa.comp))]),
     xlab = "low abundance",ylab = "leaf top 100",main = "correlation coefficients among a.a.")
cor(as.vector(cor(aa.comp.topLeaf)[upper.tri(cor(aa.comp))]),as.vector(cor(aa.comp.others)[upper.tri(cor(aa.comp))]),method = "spearman")
plot(as.vector(cor(aa.comp.others)[upper.tri(cor(aa.comp))]),as.vector(cor(aa.comp.topRoot)[upper.tri(cor(aa.comp))]),
     xlab = "low abundance",ylab = "root top 100",main = "correlation coefficients among a.a.")
cor(as.vector(cor(aa.comp.topRoot)[upper.tri(cor(aa.comp))]),as.vector(cor(aa.comp.others)[upper.tri(cor(aa.comp))]),method = "spearman")
# Out:
# [1] 0.1429236
# [1] 0.2641517
# Plot with title “correlation coefficients among a.a.”

# %%
options(repr.plot.width=6, repr.plot.height=6)
pheatmap(cor(aa.comp),main = "all OG")
pheatmap(cor(aa.comp.abundant),main = "abundant OG")
pheatmap(cor(aa.comp.abundantLeaf),main = "leaf abundant OG")
pheatmap(cor(aa.comp.abundantRoot),main = "root abundant OG")
pheatmap(cor(aa.comp.others),main = "low-abundance OG")
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
# PCA.aa.comp.abundant = prcomp(aa.comp.abundant[commonID,])
# PCA.aa.comp.abundantLeaf = prcomp(aa.comp.abundantLeaf[commonID,])
# PCA.aa.comp.abundantRoot = prcomp(aa.comp.abundantRoot[commonID,])
# PCA.aa.comp.topLeaf = prcomp(aa.comp.topLeaf[commonID,])
# PCA.aa.comp.topRoot = prcomp(aa.comp.topRoot[commonID,])
# PCA.aa.comp.low = prcomp(aa.comp.others[commonID,])

# options(repr.plot.width=6, repr.plot.height=6)
# plot(PCA.aa.comp.abundantLeaf$x,col = scales::alpha(rainbow(25)[as.factor(metadata[commonID,]$tribe)],.75),
#      xlim = c(-.02,.02),ylim = c(-0.03,0.02),xlab = "PC1 (66.4%)",ylab = "PC2 (24.1%)")
# # legend("topright",legend = levels(as.factor(metadata[commonID,]$tribe)),col = rainbow(25)[1:19],pch = 1)
# arrows(x0 = 0,y0 = 0,x1 = PCA.aa.comp.abundantLeaf$rotation[,1]/40,y1 = PCA.aa.comp.abundantLeaf$rotation[,2]/40,length = .1,col = "blue")
# text(PCA.aa.comp.abundantLeaf$rotation[,1]/40*1.1,PCA.aa.comp.abundantLeaf$rotation[,2]/40*1.1,labels = rownames(PCA.aa.comp$rotation),col = "blue")
# axis(3,at = seq(-0.02,0.02,0.01),labels = seq(-0.02,0.02,0.01)*40,col = "blue")
# axis(4,at = seq(-0.02,0.02,0.01),labels = seq(-0.02,0.02,0.01)*40,col = "blue")

# plot(PCA.aa.comp.abundantLeaf$x[,2:3],col = scales::alpha(rainbow(25)[as.factor(metadata[commonID,]$tribe)],.75),
#      xlim = c(-.02,.02),ylim = c(-0.03,0.02),xlab = "PC2",ylab = "PC3 (24.1%)")
# # legend("topright",legend = levels(as.factor(metadata[commonID,]$tribe)),col = rainbow(25)[1:19],pch = 1)
# arrows(x0 = 0,y0 = 0,x1 = PCA.aa.comp.abundantLeaf$rotation[,2]/40,y1 = PCA.aa.comp.abundantLeaf$rotation[,3]/40,length = .1,col = "blue")
# text(PCA.aa.comp.abundantLeaf$rotation[,2]/40*1.1,PCA.aa.comp.abundantLeaf$rotation[,3]/40*1.1,labels = rownames(PCA.aa.comp$rotation),col = "blue")
# axis(3,at = seq(-0.02,0.02,0.01),labels = seq(-0.02,0.02,0.01)*40,col = "blue")
# axis(4,at = seq(-0.02,0.02,0.01),labels = seq(-0.02,0.02,0.01)*40,col = "blue")


# options(repr.plot.width=6, repr.plot.height=6)
# plot(PCA.aa.comp.low$x,col = scales::alpha(rainbow(25)[as.factor(metadata[commonID,]$tribe)],.75),
#      xlim = c(-.02,.02),ylim = c(-0.03,0.02),xlab = "PC1 (66.4%)",ylab = "PC2 (24.1%)")
# # legend("topright",legend = levels(as.factor(metadata[commonID,]$tribe)),col = rainbow(25)[1:19],pch = 1)
# arrows(x0 = 0,y0 = 0,x1 = PCA.aa.comp.low$rotation[,1]/40,y1 = PCA.aa.comp.low$rotation[,2]/40,length = .1,col = "blue")
# text(PCA.aa.comp.low$rotation[,1]/40*1.1,PCA.aa.comp.low$rotation[,2]/40*1.1,labels = rownames(PCA.aa.comp$rotation),col = "blue")
# axis(3,at = seq(-0.02,0.02,0.01),labels = seq(-0.02,0.02,0.01)*40,col = "blue")
# axis(4,at = seq(-0.02,0.02,0.01),labels = seq(-0.02,0.02,0.01)*40,col = "blue")

# %% [markdown]
# ## comparison to chloroplast-encoded proteins

# %%
# henryDat = read.csv("/workdir/sh2246/p_phyloGWAS/data/Henry_processed_data.csv",header = T)

# dim(henryDat)

# options(repr.plot.width=6, repr.plot.height=6)
# plot(unlist(henryDat[grep("Zea",henryDat$Path),AA_ALPHABET[1:20]]),as.vector(aa.comp[788,]),
#      xlab = "Chloroplast",ylab = "Nucleus",pch = "",asp= 1, main = "Zea mays")
# abline(a= 0, b= 1,col = "blue")
# text(unlist(henryDat[grep("Zea",henryDat$Path),AA_STANDARD]),as.vector(aa.comp[788,]),AA_STANDARD,cex = 1.5)
# plot(sort(unlist(henryDat[grep("Zea",henryDat$Path),AA_ALPHABET[1:20]])),sort(as.vector(aa.comp[788,])))
# abline(a= 0, b= 1)

# %% [markdown]
# ## photosynthetic genes from Jonathan

# %%
photoGene = read.table("/workdir/sh2246/p_phyloGWAS/output/photo_gene_OG_20250225.txt",header = F)[,1]
buscoGene = read.table("/workdir/sh2246/p_phyloGWAS/data/busco_gene_OG_20250828.txt",header = F)[,1]
randomOG = sample(setdiff(names(aaFastaPerOG),photoGene),length(photoGene))

# %%
length(photoGene)
table(abundantOGLeaf%in%photoGene)
table(abundantOGRoot%in%photoGene)
table(abundantOGLeaf%in%buscoGene)
table(abundantOGRoot%in%buscoGene)
# Out:
# [1] 111
# FALSE  TRUE
#  1667    77
# FALSE  TRUE
#   589     1
# FALSE  TRUE
#  1485   259
# FALSE  TRUE
#   566    24

# %%
aa.comp.photo = apply(aa.comp.perOG.array[,,photoGene],c(1,2),function(x) sum(x,na.rm = T))
aa.comp.photo = aa.comp.photo/rowSums(aa.comp.photo)
aa.comp.busco = apply(aa.comp.perOG.array[,,buscoGene],c(1,2),function(x) sum(x,na.rm = T))
aa.comp.busco = aa.comp.busco/rowSums(aa.comp.busco)
aa.comp.random = apply(aa.comp.perOG.array[,,randomOG],c(1,2),function(x) sum(x,na.rm = T))
aa.comp.random = aa.comp.random/rowSums(aa.comp.random)

# %%
plot(as.vector(aa.comp.photo[grep("Zm-B73",commonID),]),as.vector(aa.comp.random[grep("Zm-B73",commonID),]),
     xlab = "Photosynthetic",ylab = "random others",pch = "",asp= 1, main = "Zea mays")
abline(a= 0, b= 1,col = "blue")
text(as.vector(aa.comp.photo[grep("Zm-B73",commonID),]),as.vector(aa.comp.random[grep("Zm-B73",commonID),]),AA_STANDARD,cex = 1.5)
# Out:
# Plot with title “Zea mays”

# %%
plot(as.vector(aa.comp.busco[grep("Zm-B73",commonID),]),as.vector(aa.comp[grep("Zm-B73",commonID),]),
     xlab = "BUSCO",ylab = "all OG",pch = "",asp= 1, main = "Zea mays")
abline(a= 0, b= 1,col = "blue")
text(as.vector(aa.comp.busco[grep("Zm-B73",commonID),]),as.vector(aa.comp[grep("Zm-B73",commonID),]),AA_STANDARD,cex = 1.5)
# Out:
# Plot with title “Zea mays”

# %%
plot(as.vector(aa.comp[grep("Zm-B73",commonID),]),as.vector(aa.comp.random[grep("Zm-B73",commonID),]),
     xlab = "fullset",ylab = "random",pch = "",asp= 1, main = "Zea mays")
abline(a= 0, b= 1,col = "blue")
text(as.vector(aa.comp[grep("Zm-B73",commonID),]),as.vector(aa.comp.random[grep("Zm-B73",commonID),]),AA_STANDARD,cex = 1.5)
# Out:
# Plot with title “Zea mays”

# %%
pheatmap::pheatmap(cor(aa.comp.photo))
pheatmap::pheatmap(cor(aa.comp.random))
pheatmap::pheatmap(cor(aa.comp.busco))
pheatmap::pheatmap(cor(aa.comp))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %%
options(repr.plot.width=16, repr.plot.height=6)
par(mfrow = c(1,2))
boxplot(aa.comp,main = "all OGs")
boxplot(aa.comp.busco,main = "BUSCO OG")
# Out:
# Plot with title “BUSCO OG”

# %%
options(repr.plot.width=6, repr.plot.height=6)
plot(as.vector(cor(aa.comp)[upper.tri(cor(aa.comp))]),as.vector(cor(aa.comp.busco)[upper.tri(cor(aa.comp))]),
     xlab = "all OGs",ylab = "BUSCO OGs",main = "correlation coefficients among a.a.")
cor(as.vector(cor(aa.comp)[upper.tri(cor(aa.comp))]),as.vector(cor(aa.comp.busco)[upper.tri(cor(aa.comp))]),method = "spearman")
# Out:
# [1] 0.8041754
# Plot with title “correlation coefficients among a.a.”

# %%
options(repr.plot.width=6, repr.plot.height=6)
pheatmap::pheatmap(cor(aa.comp),main = "all OGs")
pheatmap::pheatmap(cor(aa.comp.busco),main = "BUSCO OGs")
# Out:
# plot without title
# plot without title

# %% [markdown]
# # aa to proteome physiochemical properties

# %%
aa3 <- c(A="Ala", R="Arg", N="Asn", D="Asp", C="Cys",
         Q="Gln", E="Glu", G="Gly", H="His", I="Ile",
         L="Leu", K="Lys", M="Met", F="Phe", P="Pro",
         S="Ser", T="Thr", W="Trp", Y="Tyr", V="Val",
         B="Asx", Z="Glx", J="Xle", X="Xaa", U="Sec", O="Pyl", "*"="Stop")

one_to_three <- function(x) {
    res <- unname(aa3[toupper(x)])
    return(res)
}

aa.comp1 = aa.comp
aa.comp1.abundant = aa.comp.abundant
aa.comp1.abundantLeaf = aa.comp.abundantLeaf
aa.comp1.abundantRoot = aa.comp.abundantRoot
aa.comp1.busco = aa.comp.busco
aa.comp1.others = aa.comp.others

colnames(aa.comp1) = one_to_three(colnames(aa.comp))
colnames(aa.comp1.busco) = one_to_three(colnames(aa.comp.busco))
colnames(aa.comp1.abundant) = one_to_three(colnames(aa.comp.abundant))
colnames(aa.comp1.abundantLeaf) = one_to_three(colnames(aa.comp.abundantLeaf))
colnames(aa.comp1.abundantRoot) = one_to_three(colnames(aa.comp.abundantRoot))
colnames(aa.comp1.others) = one_to_three(colnames(aa.comp.others))

# %%
aa.feat = canprot::calc_metrics(aa.comp1,metrics = c("GRAVY","MW","Density","NC","Cost"))
aa.feat.abundant = canprot::calc_metrics(aa.comp1.abundant,metrics = c("GRAVY","MW","Density","NC","Cost"))
aa.feat.abundantLeaf = canprot::calc_metrics(aa.comp1.abundantLeaf,metrics = c("GRAVY","MW","Density","NC","Cost"))
aa.feat.abundantRoot = canprot::calc_metrics(aa.comp1.abundantRoot,metrics = c("GRAVY","MW","Density","NC","Cost"))
aa.feat.busco = canprot::calc_metrics(aa.comp1.busco,metrics = c("GRAVY","MW","Density","NC","Cost"))
aa.feat.low = canprot::calc_metrics(aa.comp1.others,metrics = c("GRAVY","MW","Density","NC","Cost"))

# %% [markdown]
# ### number of N atom per amino acid residue (N budget?)

# %%
# Alanine	A	Ala	1
# Arginine	R	Arg	4
# Asparagine	N	Asn	2
# Aspartic Acid	D	Asp	1
# Cysteine	C	Cys	1
# Glutamine	Q	Gln	2
# Glutamic Acid	E	Glu	1
# Glycine	G	Gly	1
# Histidine	H	His	3
# Isoleucine	I	Ile	1
# Leucine	L	Leu	1
# Lysine	K	Lys	2
# Methionine	M	Met	1
# Phenylalanine	F	Phe	1
# Proline	P	Pro	1
# Serine	S	Ser	1
# Threonine	T	Thr	1
# Tryptophan	W	Trp	2
# Tyrosine	Y	Tyr	1
# Valine	V	Val	1

NInAA = c(1,4,2,1,1,2,1,1,3,1,1,2,1,1,1,1,1,2,1,1)
names(NInAA) = c("A","R","N","D","C","Q","E","G","H","I","L","K","M","F","P","S","T","W","Y","V")

NperAA = as.matrix(aa.comp)%*%NInAA[colnames(aa.comp)]

names(NperAA) = rownames(aa.comp)

hist(NperAA)

head(sort(NperAA),10)
tail(sort(NperAA),10)
# Out:
#                      Oat_OT3098_v2                  Festuca_brevipila
#                           1.364396                           1.364430
#                        SRR14924115                      FRR_PoAnn_1.0
#                           1.364628                           1.364789
#                        SRR14867315   Avena_sativa_cv_Sang_v1_assembly
#                           1.364844                           1.364963
# Avena_insularis_BYU209_v1_assembly                       ASM2364667v1
#                           1.365020                           1.365225
#                       ASM2361440v1           10wheat_assembly_stanley
#                           1.365254                           1.365364
#                 ASM151433v2                ASM2264469v1
#                    1.380609                    1.380688
#            Sugarcane_genome Sn-CAM1369-DRAFT-PanAnd-1.0
#                    1.380850                    1.382291
# ...

# %%
LSD::heatscatter(as.numeric(NperAA),as.numeric(aa.feat$NC))
cor(NperAA,aa.feat$NC)
# Out:
#      [,1]
# [1,] 0.8274818
# Plot with title “”

# %% [markdown]
# # GC content calculation (CDS only)

# %%
dnaFasta = mclapply(list.files("/workdir/sh2246/p_phyloGWAS/output/CDSperTaxa/",pattern = "*.fa",full.names = T),function(x) readAAStringSet(x),mc.cores = 30)

dna.comp = mclapply(dnaFasta,function(x){
    tmp = letterFrequency(x,letters = c("A","T","C","G"))
    return(colSums(tmp)/sum(tmp))
},mc.cores = 30)


dna.comp = Reduce("rbind",dna.comp)

rownames(dna.comp) = gsub(".fa","",list.files("/workdir/sh2246/p_phyloGWAS/output/CDSperTaxa/",pattern = "*.fa"))

dna.comp = dna.comp[commonID,]

dim(dna.comp)
# Out:
# [1] 687   4

# %%
fwrite(dna.comp,"/workdir/sh2246/p_phyloGWAS/output/poaceae_dnaComposition_20251008.txt",sep = "\t",row.names = T,col.names = T)
# Out:
# x being coerced from class: matrix to data.table

# %%
dna.comp = read.table("/workdir/sh2246/p_phyloGWAS/output/poaceae_dnaComposition_20251008.txt",row.names =1,header = T)

# %%
cgCont = rowSums(dna.comp[,3:4])

# %%
dnaFastaPerOG = mclapply(list.files("/workdir/sh2246/p_phyloGWAS/output/CDSMSAPerOG/",pattern = "*.fa",full.names = T),
                         function(x) readDNAStringSet(x),mc.cores = 5)

names(dnaFastaPerOG) = gsub("_mafft.fa","",list.files("/workdir/sh2246/p_phyloGWAS/output/CDSMSAPerOG/",pattern = "*.fa"))
dna.comp.perOG = mclapply(dnaFastaPerOG,function(x){
    tmp = letterFrequency(x,letters = c("A","T","C","G"))
    rownames(tmp) = names(x)
    tmp = apply(tmp,2,function(a) tapply(a,limma::strsplit2(rownames(tmp),":")[,2],sum))
    return(as.data.frame(tmp)[commonID,])
},mc.cores = 5)


dna.comp.perOG.array = simplify2array(lapply(dna.comp.perOG,as.matrix))

# %%
dna.prop.perOG = array(apply(dna.comp.perOG.array,3,function(x) x/rowSums(x,na.rm = T)),dim = dim(dna.comp.perOG.array))
dimnames(dna.prop.perOG) = dimnames(dna.comp.perOG.array)

# %%
cgCont.new = apply(dna.comp.perOG.array,c(1,2),sum,na.rm = T)
cgCont.new = rowSums(cgCont.new[,3:4]/rowSums(cgCont.new))

# %%
cgCont.abundant = apply(dna.comp.perOG.array[,,intersect(abundantOG,dimnames(dna.prop.perOG)[[3]])],c(1,2),sum,na.rm = T)
cgCont.abundant = rowSums(cgCont.abundant[,3:4]/rowSums(cgCont.abundant))
cgCont.abundantLeaf = apply(dna.comp.perOG.array[,,intersect(abundantOGLeaf,dimnames(dna.prop.perOG)[[3]])],c(1,2),sum,na.rm = T)
cgCont.abundantLeaf = rowSums(cgCont.abundantLeaf[,3:4]/rowSums(cgCont.abundantLeaf))
cgCont.abundantRoot = apply(dna.comp.perOG.array[,,intersect(abundantOGRoot,dimnames(dna.prop.perOG)[[3]])],c(1,2),sum,na.rm = T)
cgCont.abundantRoot = rowSums(cgCont.abundantRoot[,3:4]/rowSums(cgCont.abundantRoot))
cgCont.topLeaf = apply(dna.comp.perOG.array[,,intersect(topOGLeaf,dimnames(dna.prop.perOG)[[3]])],c(1,2),sum,na.rm = T)
cgCont.topLeaf = rowSums(cgCont.topLeaf[,3:4]/rowSums(cgCont.topLeaf))
cgCont.topRoot = apply(dna.comp.perOG.array[,,intersect(topOGRoot,dimnames(dna.prop.perOG)[[3]])],c(1,2),sum,na.rm = T)
cgCont.topRoot = rowSums(cgCont.topRoot[,3:4]/rowSums(cgCont.topRoot))

# %%
cgCont.low = apply(dna.comp.perOG.array[,,setdiff(dimnames(dna.prop.perOG)[[3]],abundantOG)],c(1,2),sum,na.rm = T)
cgCont.low = rowSums(cgCont.low[,3:4]/rowSums(cgCont.low))

# %%
LSD::heatscatter(cgCont.abundantLeaf,cgCont.abundantRoot,main = "CDS GC",
                 xlab = "Leaf abundant",ylab = "Root abundant")
abline(a = 0, b =1, col = "blue",lty = 2)
# Out:
# Plot with title “”

# %%
LSD::heatscatter(cgCont.abundantLeaf,cgCont.low,main = "CDS GC",
                 xlab = "Leaf Abundant",ylab = "Low abundance")
abline(a = 0, b =1, col = "blue",lty = 2)
# Out:
# Plot with title “”

# %%
hist(cgCont.abundantLeaf,breaks = seq(0.5,.62,.005),col = alpha("forestgreen",.5),main = "",xlab = "CDS GC")
hist(cgCont.abundantRoot,breaks = seq(0.5,.62,.005),col = alpha("darkgoldenrod",.5),add =T)
# Out:
# Plot with title “”

# %%
# number of N atoms in mRNA/tRNA
NInDNA = c(5,2,3,5)
names(NInDNA) = c("A","T","C","G")

NperDNA = as.matrix(dna.comp)%*%NInDNA[colnames(dna.comp)]

names(NperDNA) = rownames(dna.comp)

# %%
sd(cgCont)/mean(cgCont)
mean(cgCont)
range(cgCont)
# Out:
# [1] 0.01593315
# [1] 0.5484232
# [1] 0.5158172 0.5884468

# %%
cor(cbind(dna.comp,cgCont,NperDNA))
# Out:
#         A          T          C          G          cgCont     NperDNA
# A        1.0000000  0.9863810 -0.9869398 -0.9884647 -0.9966164 -0.8830082
# T        0.9863810  1.0000000 -0.9938975 -0.9781655 -0.9965624 -0.9190315
# C       -0.9869398 -0.9938975  1.0000000  0.9624964  0.9937942  0.8699416
# G       -0.9884647 -0.9781655  0.9624964  1.0000000  0.9867006  0.9336272
# cgCont  -0.9966164 -0.9965624  0.9937942  0.9867006  1.0000000  0.9040319
# NperDNA -0.8830082 -0.9190315  0.8699416  0.9336272  0.9040319  1.0000000

# %%
# raw reads estimates

# %%
# gc_rawreads = read.delim("/workdir/sh2246/p_phyloGWAS/data/multiqc_by_sampleid_combined12.txt")

# gc_rawreads$sampleid = gsub("merged","",gc_rawreads$sampleid)

# rownames(gc_rawreads) = gc_rawreads$sampleid

# %%
gc()
# Out:
#        used     (Mb)  gc trigger (Mb)  max used (Mb)
# Ncells  5639279 301.2 10537588   562.8  8505616 454.3
# Vcells 10232618  78.1 18516114   141.3 15363429 117.3

# %%
cor(cbind(aa.feat,cgCont),method = "spearman")
# Out:
#         GRAVY       MW          Density     NC          Cost       cgCont
# GRAVY    1.00000000 -0.24582915 -0.50181609 -0.01357701  0.2011270  0.5177916
# MW      -0.24582915  1.00000000  0.09410156 -0.59483017  0.8185142 -0.6795216
# Density -0.50181609  0.09410156  1.00000000 -0.48863064 -0.2882008 -0.3244912
# NC      -0.01357701 -0.59483017 -0.48863064  1.00000000 -0.4131340  0.4683187
# Cost     0.20112695  0.81851416 -0.28820076 -0.41313400  1.0000000 -0.3343997
# cgCont   0.51779156 -0.67952157 -0.32449125  0.46831870 -0.3343997  1.0000000

# %%
pheatmap(cor(cbind(aa.comp,aa.feat,"GC" = cgCont),method = "pearson"))
pheatmap(cor(cbind(aa.comp,aa.feat,"GC" = cgCont),method = "spearman"))
# Out:
# plot without title
# plot without title

# %% [markdown]
# # Modeling

# %%
metadataPlus$pacbio = as.factor(grepl("pacbio",metadataPlus$technology,ignore.case = T))
dat = merge(metadataPlus,envDf,by = "assemblyID")
rownames(dat) = dat$assemblyID

# %%
myX = cbind(aa.feat,"GC" = cgCont[commonID])
myX2 = cbind(aa.feat.abundant,"GC" = cgCont.abundant[commonID])
myX3 = cbind(aa.feat.abundantLeaf,"GC" = cgCont.abundantLeaf[commonID])
myX4 = cbind(aa.feat.abundantRoot,"GC" = cgCont.abundantRoot[commonID])
myX5 = cbind(aa.feat.low,"GC" = cgCont.low[commonID])

# %%
fwrite(myX,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureData_20251008.txt",quote = F, row.name =T,sep = "\t")
fwrite(myX2,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureData_abundant_20251008.txt",quote = F, row.name =T,sep = "\t")
fwrite(myX3,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureData_abundantLeaf_20251008.txt",quote = F, row.name =T,sep = "\t")
fwrite(myX4,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureData_abundantRoot_20251008.txt",quote = F, row.name =T,sep = "\t")
fwrite(myX5,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureData_low_20251008.txt",quote = F, row.name =T,sep = "\t")

# %%
myX = read.table("/workdir/sh2246/p_phyloGWAS/output/genomicFeatureData_20251008.txt",row.names = 1)
myX2 = read.table("/workdir/sh2246/p_phyloGWAS/output/genomicFeatureData_abundant_20251008.txt",row.names = 1)
myX3 = read.table("/workdir/sh2246/p_phyloGWAS/output/genomicFeatureData_abundantLeaf_20251008.txt",row.names = 1)
myX4 = read.table("/workdir/sh2246/p_phyloGWAS/output/genomicFeatureData_abundantRoot_20251008.txt",row.names = 1)
myX5 = read.table("/workdir/sh2246/p_phyloGWAS/output/genomicFeatureData_low_20251008.txt",row.names = 1)

# %%
myX = as.data.frame(myX)
myX2 = as.data.frame(myX2)
myX3 = as.data.frame(myX3)
myX4 = as.data.frame(myX4)
myX5 = as.data.frame(myX5)

# %%
scaledDat = apply(myX,2,function(x) (x-mean(x))/sd(x))
scaledDat2 = apply(myX2,2,function(x) (x-mean(x))/sd(x))
scaledDat3 = apply(myX3,2,function(x) (x-mean(x))/sd(x))
scaledDat4 = apply(myX4,2,function(x) (x-mean(x))/sd(x))
scaledDat5 = apply(myX5,2,function(x) (x-mean(x))/sd(x))

# %%
dat1= cbind(dat[commonID,],scaledDat)
dat1$assemblyID = as.factor(dat1$assemblyID)

dat2= cbind(dat[commonID,],scaledDat2)
dat2$assemblyID = as.factor(dat1$assemblyID)

dat3= cbind(dat[commonID,],scaledDat3)
dat3$assemblyID = as.factor(dat3$assemblyID)

dat4= cbind(dat[commonID,],scaledDat4)
dat4$assemblyID = as.factor(dat4$assemblyID)

dat5= cbind(dat[commonID,],scaledDat5)
dat5$assemblyID = as.factor(dat5$assemblyID)

# %%
# dat1$lifeHistoryNumeric = as.numeric(dat1$lifeHistory=="perennial")
# dat1$lifeHistoryNumeric[dat1$lifeHistory=="annual or perennial"] = NA

# fwrite(dat1,"/workdir/sh2246/p_phyloGWAS/output/masterDataTablePerAsm_2025.08.28.txt",sep = "\t",quote = F)

# %%
options(repr.plot.width=6, repr.plot.height=6)
pheatmap(cor(dat1[,c("GRAVY","MW","Density","NC","Cost","GC")],
             use = "pairwise.complete.obs",method = "pearson"),
        display_number = T)
# Out:
# plot without title

# %%
options(repr.plot.width=6, repr.plot.height=6)
pheatmap(cor(dat1[,c("GRAVY","MW","Density","NC","Cost","GC")],
             use = "pairwise.complete.obs",method = "spearman"),
        display_number = T)
# Out:
# plot without title

# %%
R2phylo = c()
for (i in c("GRAVY","MW","Density","NC","Cost","GC")){
    myF1 = as.formula(paste0(i, "~ compdup + pacbio"))
    myF2 = as.formula(paste0(i, "~ 1"))
    model_Covariate <- asreml(fixed = myF1,random = ~ vm(assemblyID, phyloKMat),
                              ai.sing = F, data = dat1)

    R2phylo = c(R2phylo,summary(model_Covariate)$varcomp$component[1]/sum(summary(model_Covariate)$varcomp$component)) 
}
# Out:
# ASReml Version 4.2 09/10/2025 17:54:23
#           LogLik        Sigma2     DF     wall
#  1     -179.2190     0.5715382    684   17:54:24
#  2     -172.3185     0.5517592    684   17:54:24
#  3     -163.2426     0.5207514    684   17:54:24
#  4     -155.6906     0.4852988    684   17:54:24
#  5     -151.8005     0.4526184    684   17:54:24
#  6     -151.1730     0.4378138    684   17:54:24
#  7     -151.1385     0.4340789    684   17:54:24
#  8     -151.1378     0.4335317    684   17:54:24
# ASReml Version 4.2 09/10/2025 17:54:25
#           LogLik        Sigma2     DF     wall
#  1     -218.6256     0.6413372    684   17:54:25
#  2     -195.8923     0.5877214    684   17:54:25
#  3     -166.5382     0.5159497    684   17:54:25
#  4     -141.9978     0.4462995    684   17:54:25
#  5     -127.7616     0.3867001    684   17:54:26
#  6     -124.2677     0.3549907    684   17:54:26
#  7     -123.8919     0.3436477    684   17:54:26
#  8     -123.8769     0.3412733    684   17:54:26
# ...

# %%
names(R2phylo) = c("GRAVY","MW","Density","NC","Cost","GC")
R2phylo
# Out:
#     GRAVY        MW   Density        NC      Cost        GC
# 0.5621157 0.7606938 0.7707570 0.8063822 0.7568141 0.8369094

# %%
# Custom histogram panel (diagonal)
panel.hist <- function(x, ...) {
  usr <- par("usr"); on.exit(par(usr = usr))
  h <- hist(x, plot = FALSE)
  breaks <- h$breaks
  y <- h$counts / sum(h$counts)  # Normalize to probability density
  y <- y / max(y)                # Rescale to [0,1]
  
  par(usr = c(min(breaks), max(breaks), 0, 1.5))
  rect(breaks[-length(breaks)], 0, breaks[-1], y, col = "lightgray", border = NULL)
#     text(median(x),1.25)
}

# Custom correlation panel (upper triangle)
panel.cor <- function(x, y, digits = 2, prefix = "", cex.cor = 1.2, ...) {
  usr <- par("usr"); on.exit(par(usr = usr))
  par(usr = c(0, 1, 0, 1))
  r <- cor(x, y, use = "complete.obs",method = "pearson")
  txt <- formatC(r, format = "f", digits = digits)
  text(0.5, 0.5, paste0(prefix, txt), cex = cex.cor )
}

# Custom heat.scatter panel (lower triangle)
panel.heat <- function(x, y, ...) {
  usr <- par("usr"); on.exit(par(usr = usr))
  par(new = TRUE)
  LSD::heatscatter(x, y, xlab = "", ylab = "", xaxt = "n", yaxt = "n", main = "" )
}

# %%
options(repr.plot.width=8, repr.plot.height=8)
pairs(myX,labels = c("GRAVY","MW","Density","NC","Cost","GC"),
      diag.panel = panel.hist,
      lower.panel = panel.heat,
      upper.panel = panel.cor,cex = 1.5,cex.axis = 1.5)
# Out:
# Plot with title “”

# %%
png("/workdir/sh2246/p_phyloGWAS/output/figure/Fig4a_v2.png",width = 8.7*1.5,height = 8.7*1.5,units = "cm",
    res = 600,pointsize = 8)
pairs(myX,labels = c("GRAVY","MW","Density","NC","Cost","GC"),
      diag.panel = panel.hist,
      lower.panel = panel.heat,
      upper.panel = panel.cor,cex = 1.5,cex.axis = 1.5)
dev.off()
# Out:
# pdf
#   2

# %%
png("/workdir/sh2246/p_phyloGWAS/output/figure/Fig4b_v3.png",width = 8.7*.65,height = 8.7*1.3,units = "cm",
    res = 600,pointsize = 8)
par(mar = c(3,5,0,1))
bp=barplot(rev(R2phylo)*100,horiz = T,las =1,space = 1.5,main = "",xlim = c(0,100),ylim = c(1.2,15.7))
text(y= bp, x = round(rev(R2phylo),3)*100,labels = round(rev(R2phylo),3)*100,pos = 2)
dev.off()
# Out:
# pdf
#   2

# %%
fit_model <- function(data, Kmat,responseVar,predictor) {
#   library(asreml)
    gc()
    asreml.options(verbose = FALSE)
    Coeff = c()
    WaldPval = c()
    for (i in predictor){
        fullFM = as.formula(paste0(responseVar, "~", i ,"+ compdup + pacbio"))
        model_full <- asreml(fixed = fullFM,
                             random = ~ vm(assemblyID, Kmat) , ai.sing = F, data = data)

        modelWald <- wald.asreml(model_full)
        if(model_full$converge) {
            Coeff <- c(Coeff,model_full$coefficients$fixed[2])
            WaldPval <- c(WaldPval,modelWald[2,4])
        }else {
            Coeff <- c(Coeff,NA)
            WaldPval <- c(WaldPval,NA)
        }
    }
    
    out = c(Coeff,WaldPval)
    names(out) = c(paste("Coeff",predictor,sep = "_"),
                   paste("P",predictor,sep = "_"))
    return(out)
}

# %%
gc()
# Out:
#        used       (Mb)    gc trigger (Mb)    max used    (Mb)
# Ncells   28988779  1548.2   51731987  2762.8    51731987  2762.8
# Vcells 3092182058 23591.5 8573067324 65407.4 11162638606 85164.2

# %%
asreml.options(maxit = 30,verbose = F)
fit_model(dat1,phyloKMat,"TN1_GSDE_5_quan50",c("GRAVY","MW","Density","NC","Cost","GC"))
# Out:
# ASReml Version 4.2 08/10/2025 19:46:11
#           LogLik        Sigma2     DF     wall
#  1     -1403.931      20.46578    683   19:46:11
#  2     -1399.194      19.86799    683   19:46:12
#  3     -1393.895      19.01904    683   19:46:12
#  4     -1390.624      18.18934    683   19:46:12
#  5     -1389.526      17.54793    683   19:46:12
#  6     -1389.452      17.35920    683   19:46:12
#  7     -1389.451      17.33554    683   19:46:12
# ASReml Version 4.2 08/10/2025 19:46:12
#           LogLik        Sigma2     DF     wall
#  1     -1404.731      20.51032    683   19:46:12
#  2     -1399.741      19.89467    683   19:46:13
#  3     -1394.128      19.01892    683   19:46:13
#  4     -1390.642      18.16208    683   19:46:13
#  5     -1389.470      17.49993    683   19:46:13
#  6     -1389.393      17.30689    683   19:46:13
#  7     -1389.392      17.28420    683   19:46:13
# ASReml Version 4.2 08/10/2025 19:46:13
#           LogLik        Sigma2     DF     wall
# ...

# %%
testMLM = mclapply(c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50"),
                function(x) fit_model(dat1,phyloKMat,x,c("GRAVY","MW","Density","NC","Cost","GC")),mc.cores = 13)

testMLM = t(simplify2array(testMLM))
testMLM = as.data.frame(testMLM)
rownames(testMLM) = c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50")

# %%
testMLM2 = mclapply(c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50"),
                function(x) fit_model(dat2,phyloKMat,x,c("GRAVY","MW","Density","NC","Cost","GC")),mc.cores = 13)

testMLM2 = t(simplify2array(testMLM2))
testMLM2 = as.data.frame(testMLM2)
rownames(testMLM2) = c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50")

# %%
testMLM3 = mclapply(c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50"),
                function(x) fit_model(dat3,phyloKMat,x,c("GRAVY","MW","Density","NC","Cost","GC")),mc.cores = 13)

testMLM3 = t(simplify2array(testMLM3))
testMLM3 = as.data.frame(testMLM3)
rownames(testMLM3) = c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50")

# %%
testMLM4 = mclapply(c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50"),
                function(x) fit_model(dat4,phyloKMat,x,c("GRAVY","MW","Density","NC","Cost","GC")),mc.cores = 13)

testMLM4 = t(simplify2array(testMLM4))
testMLM4 = as.data.frame(testMLM4)
rownames(testMLM4) = c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50")

# %%
testMLM5 = mclapply(c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50"),
                function(x) fit_model(dat5,phyloKMat,x,c("GRAVY","MW","Density","NC","Cost","GC")),mc.cores = 13)

testMLM5 = t(simplify2array(testMLM5))
testMLM5 = as.data.frame(testMLM5)
rownames(testMLM5) = c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50")

# %%
testGLM = mclapply(c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50"),
                function(x) fit_model_glm(dat1,phyloKMat,x),mc.cores = 13)

testGLM = t(simplify2array(testGLM))
testGLM = as.data.frame(testGLM)
rownames(testGLM) = c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50")

testMLM_andro = mclapply(c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50"),
                function(x) fit_model(dat1[dat1$tribe %in% 'Andropogoneae',],phyloKMat,x),mc.cores = 13)

testMLM_andro = t(simplify2array(testMLM_andro))
testMLM_andro = as.data.frame(testMLM_andro)
rownames(testMLM_andro) = c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50")

testGLM_andro = mclapply(c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50"),
                function(x) fit_model_glm(dat1[dat1$tribe %in% 'Andropogoneae',],phyloKMat,x),mc.cores = 13)

testGLM_andro = t(simplify2array(testGLM_andro))
testGLM_andro = as.data.frame(testGLM_andro)
rownames(testGLM_andro) = c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50")
# Out:
#           LogLik        Sigma2     DF     wall
#  1     -1466.852      22.73663    704   16:25:01
# ASReml Version 4.2 10/09/2025 16:25:01
#           LogLik        Sigma2     DF     wall
#  1     -367.8707      1.001874    704   16:25:01

# %%
fwrite(testMLM,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureAssociation_MLM.txt",sep = "\t",quote = F,row.names = T)
fwrite(testMLM2,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureAssociation_abundant_MLM.txt",sep = "\t",quote = F,row.names = T)
fwrite(testMLM3,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureAssociation_abundantL_MLM.txt",sep = "\t",quote = F,row.names = T)
fwrite(testMLM4,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureAssociation_MLM.txt",sep = "\t",quote = F,row.names = T)
fwrite(testMLM5,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureAssociation_MLM.txt",sep = "\t",quote = F,row.names = T)
# fwrite(testGLM,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureAssociation_GLM.txt",sep = "\t",quote = F,row.names = T)
# fwrite(testMLM_andro,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureAssociation_MLM_andro.txt",sep = "\t",quote = F,row.names = T)
# fwrite(testGLM_andro,"/workdir/sh2246/p_phyloGWAS/output/genomicFeatureAssociation_GLM_andro.txt",sep = "\t",quote = F,row.names = T)

# %%
testMLM = read.delim("/workdir/sh2246/p_phyloGWAS/output/genomicFeatureAssociation_MLM.txt",header = T,row.names = 1)
testGLM = read.delim("/workdir/sh2246/p_phyloGWAS/output/genomicFeatureAssociation_GLM.txt",header = T,row.names = 1)

# %%
testMLM
# Out:
#                                               Coeff_GRAVY  Coeff_MW
# envPC_1                                        0.019986305 -0.010112070
# envPC_2                                        0.001588313 -0.068811847
# envPC_3                                       -0.074246657  0.047270823
# envPC_4                                       -0.049500746  0.031047176
# envPC_5                                        0.018072982  0.009340198
# envPC_6                                        0.018569782  0.094651847
# envPC_7                                       -0.017262797 -0.001825904
# envPC_8                                        0.007956646 -0.084432651
# envPC_9                                        0.029216560  0.045211124
# envPC_10                                      -0.052539973  0.020176691
# TN1_GSDE_5_quan50                              0.155279593  0.171359196
# TC1_GSDE_5_quan50                              3.252786437 -3.540828967
# ...

# %% [markdown]
# # permulation

# %%
# load tree
spTre = read.tree("/workdir/sh2246/p_phyloGWAS/output/PoaceaeTree_angiosperm353_astral_filtered_20250407.nwk")
spTre = keep.tip(spTre,rownames(envDf))
spTre.rooted = root(spTre,"ASM1935983v1")
spTre.rooted$edge.length[is.na(spTre.rooted$edge.length)] = 0.1 # to fill tip branch length

spTre.rooted.resolved = ape::multi2di(spTre.rooted)

# %%
envPC_perm = list()
set.seed(123)
for (j in 1:5){
    envPC_perm[[j]] = rownames(envDf)
    for (i in 1:1000){
        # trait vector
        trait_test = envDf[,grepl("envPC",colnames(envDf))][,j]
        names(trait_test) = rownames(envDf)

        # rate estimates and simulation
        rate_test = ratematrix(spTre.rooted.resolved, trait_test)
        trait_sim = sim.char(spTre.rooted.resolved,rate_test,nsim = 1)
        envPC_perm[[j]] = data.frame(envPC_perm[[j]],sort(trait_test)[rank(trait_sim[,,1])])    
    }
#     envPC_perm[[j]] = cbind(rownames(envDf),envPC_perm[[j]])
    colnames(envPC_perm[[j]]) = c("assemblyID",paste0("envPC",j,"_",1:1000))
}

# %%
testMLM_perm= list()
for (i in 1:5){
    tmpDat = merge(dat1,envPC_perm[[i]],by = 'assemblyID')
    tmpName = colnames(tmpDat)[grep(paste0("envPC",i),colnames(tmpDat))]

    testMLM_perm[[i]] = mclapply(tmpName,
                            function(x) fit_model(tmpDat,phyloKMat,x,c("GRAVY","MW","Density","NC","Cost","GC")),
                                 mc.cores = 20)

    testMLM_perm[[i]] = t(simplify2array(testMLM_perm[[i]]))
    testMLM_perm[[i]] = as.data.frame(testMLM_perm[[i]])
    rownames(testMLM_perm[[i]]) = tmpName
}
# Out:
#   LogLik        Sigma2     DF     wall
#  1     -270.3219     0.7399258    683   21:24:51
#  2     -244.4675     0.6693683    683   21:24:52
#  4     -127.2186     0.3900773    683   21:24:52
#  3     -204.0360     0.5609996    683   21:24:52
#  5     -99.13071     0.3056871    683   21:24:52
#  4     -160.6456     0.4433736    683   21:24:52
#  6     -92.81210     0.2672670    683   21:24:52
#  5     -125.9595     0.3373763    683   21:24:52
#  7     -92.31593     0.2557740    683   21:24:52
#  6     -111.3496     0.2736929    683   21:24:52
#  8     -92.30953     0.2544050    683   21:24:52
#  7     -108.0259     0.2438449    683   21:24:52
#  8     -107.7023     0.2342793    683   21:24:52
#  9     -107.6899     0.2323644    683   21:24:52
# 10     -107.6896     0.2320779    683   21:24:53
# ASReml Version 4.2 08/10/2025 21:24:53
#           LogLik        Sigma2     DF     wall
#  1     -274.5036     0.7492292    683   21:24:53
# ASReml Version 4.2 08/10/2025 21:24:53
# ...

# %%
testMLM_perm2= list()
for (i in 1:5){
    tmpDat = merge(dat2,envPC_perm[[i]],by = 'assemblyID')
    tmpName = colnames(tmpDat)[grep(paste0("envPC",i),colnames(tmpDat))]

    testMLM_perm2[[i]] = mclapply(tmpName,
                            function(x) fit_model(tmpDat,phyloKMat,x,c("GRAVY","MW","Density","NC","Cost","GC")),
                                 mc.cores = 20)

    testMLM_perm2[[i]] = t(simplify2array(testMLM_perm2[[i]]))
    testMLM_perm2[[i]] = as.data.frame(testMLM_perm2[[i]])
    rownames(testMLM_perm2[[i]]) = tmpName
}
# Out:
# 64280     0.3720588    683   22:50:10
#  6     -108.0883     0.2897475    683   22:50:10
#  2     -181.3833     0.5566345    683   22:50:10
#  7     -5.257758     0.1902941    683   22:50:10
#  7     -120.3564     0.2729960    683   22:50:10
#  9     -154.5718     0.2992015    683   22:50:10
#  2     -251.2450     0.6778277    683   22:50:10
#  5     -61.29566     0.2882926    683   22:50:10
#  7     -106.6424     0.2695403    683   22:50:10
#  3     -133.5196     0.4580175    683   22:50:10
#  8     -5.060746     0.1846515    683   22:50:10
#  8     -120.3315     0.2700977    683   22:50:10
# 10     -154.5712     0.2986965    683   22:50:10
#  3     -194.7795     0.5290903    683   22:50:10
#  8     -106.5745     0.2649483    683   22:50:10
#  6     -48.87293     0.2395842    683   22:50:10
#  4     -87.93625     0.3629799    683   22:50:10
#  9     -5.056019     0.1837571    683   22:50:10
#  9     -120.3314     0.2699140    683   22:50:11
# ...

# %%
testMLM_perm3= list()
for (i in 1:5){
    tmpDat = merge(dat3,envPC_perm[[i]],by = 'assemblyID')
    tmpName = colnames(tmpDat)[grep(paste0("envPC",i),colnames(tmpDat))]

    testMLM_perm3[[i]] = mclapply(tmpName,
                            function(x) fit_model(tmpDat,phyloKMat,x,c("GRAVY","MW","Density","NC","Cost","GC")),
                                 mc.cores = 20)

    testMLM_perm3[[i]] = t(simplify2array(testMLM_perm3[[i]]))
    testMLM_perm3[[i]] = as.data.frame(testMLM_perm3[[i]])
    rownames(testMLM_perm3[[i]]) = tmpName
}
# Out:
# 7     0.5829864    683   23:59:50
#  7     -122.8405     0.3125656    683   23:59:50
#  2     -157.9292     0.5208482    683   23:59:51
#  8     -122.8347     0.3111115    683   23:59:51
# ASReml Version 4.2 08/10/2025 23:59:51
#  3     -114.9415     0.4366364    683   23:59:51
#  4     -73.31576     0.3523323    683   23:59:51
#  5     -44.16553     0.2801125    683   23:59:51
#           LogLik        Sigma2     DF     wall
#  1     -254.5366     0.7068498    683   23:59:51
#  6     -35.32742     0.2414632    683   23:59:51
#  2     -225.1359     0.6335136    683   23:59:51
#  7     -34.33573     0.2278097    683   23:59:51
#  3     -186.1982     0.5371643    683   23:59:51
#  8     -34.31560     0.2257488    683   23:59:51
#  4     -151.1846     0.4438758    683   23:59:51
#  9     -34.31557     0.2256646    683   23:59:51
#  5     -129.1136     0.3658751    683   23:59:51
# ASReml Version 4.2 08/10/2025 23:59:51
#  6     -123.5314     0.3261020    683   23:59:51
# ...

# %%
testMLM_perm4= list()
for (i in 1:5){
    tmpDat = merge(dat4,envPC_perm[[i]],by = 'assemblyID')
    tmpName = colnames(tmpDat)[grep(paste0("envPC",i),colnames(tmpDat))]

    testMLM_perm4[[i]] = mclapply(tmpName,
                            function(x) fit_model(tmpDat,phyloKMat,x,c("GRAVY","MW","Density","NC","Cost","GC")),
                                 mc.cores = 20)

    testMLM_perm4[[i]] = t(simplify2array(testMLM_perm4[[i]]))
    testMLM_perm4[[i]] = as.data.frame(testMLM_perm4[[i]])
    rownames(testMLM_perm4[[i]]) = tmpName
}
# Out:
#  -101.6567     0.2533176    683   01:09:37
#  8     -214.8995     0.3981500    683   01:09:37
#  9     -101.6349     0.2507612    683   01:09:38
#  9     -214.8994     0.3978450    683   01:09:38
# ASReml Version 4.2 09/10/2025 01:09:38
# 10     -101.6343     0.2503383    683   01:09:38
# ASReml Version 4.2 09/10/2025 01:09:38
#           LogLik        Sigma2     DF     wall
#  1     -316.0047     0.8461145    683   01:09:38
#           LogLik        Sigma2     DF     wall
#  1     -228.9645     0.6555831    683   01:09:38
#  2     -294.6482     0.7730473    683   01:09:38
#  2     -207.2710     0.6032159    683   01:09:38
#  3     -265.0466     0.6689670    683   01:09:38
#  3     -177.5351     0.5291987    683   01:09:38
#  4     -238.0826     0.5629543    683   01:09:38
#  4     -146.4606     0.4449733    683   01:09:38
#  5     -220.1484     0.4684532    683   01:09:38
#  5     -118.9799     0.3566747    683   01:09:38
#  6     -215.1756     0.4180193    683   01:09:39
# ...

# %%
testMLM_perm5= list()
for (i in 1:5){
    tmpDat = merge(dat5,envPC_perm[[i]],by = 'assemblyID')
    tmpName = colnames(tmpDat)[grep(paste0("envPC",i),colnames(tmpDat))]

    testMLM_perm5[[i]] = mclapply(tmpName,
                            function(x) fit_model(tmpDat,phyloKMat,x,c("GRAVY","MW","Density","NC","Cost","GC")),
                                 mc.cores = 20)

    testMLM_perm5[[i]] = t(simplify2array(testMLM_perm5[[i]]))
    testMLM_perm5[[i]] = as.data.frame(testMLM_perm5[[i]])
    rownames(testMLM_perm5[[i]]) = tmpName
}
# Out:
# 0.1847332    683   02:18:32
#  4     -92.22847     0.3544887    683   02:18:32
#  9     -5.044809     0.1838344    683   02:18:32
# ASReml Version 4.2 09/10/2025 02:18:32
#  5     -55.61089     0.2673273    683   02:18:32
#  6     -46.34441     0.2270247    683   02:18:32
#  7     -45.54907     0.2145931    683   02:18:33
#           LogLik        Sigma2     DF     wall
#  1     -197.7410     0.5984218    683   02:18:33
#  8     -45.54136     0.2132994    683   02:18:33
#  2     -161.3670     0.5260551    683   02:18:33
#  3     -111.5143     0.4318845    683   02:18:33
#  4     -60.99588     0.3376042    683   02:18:33
#  5     -22.11463     0.2559843    683   02:18:33
#  6     -7.680566     0.2101628    683   02:18:33
#  7     -4.967796     0.1901749    683   02:18:33
#  8     -4.772398     0.1845579    683   02:18:33
#  9     -4.767671     0.1836640    683   02:18:33
# ASReml Version 4.2 09/10/2025 02:18:33
#           LogLik        Sigma2     DF     wall
# ...

# %%
testGLM_perm= list()
for (i in 1:5){
    dat2 = merge(dat1,envPC_perm[[i]],by = 'assemblyID')
    tmpName = colnames(dat2)[grep(paste0("envPC",i),colnames(dat2))]

    testGLM_perm[[i]] = mclapply(tmpName,
                            function(x) fit_model_glm(dat2,phyloKMat,x,c("GRAVY","MW","Density","NC","Cost","GC")),mc.cores = 20)

    testGLM_perm[[i]] = t(simplify2array(testGLM_perm[[i]]))
    testGLM_perm[[i]] = as.data.frame(testGLM_perm[[i]])
    rownames(testGLM_perm[[i]]) = tmpName
}
# Out:
# ASReml Version 4.2 01/09/2025 12:18:25
#           LogLik        Sigma2     DF     wall
#  1     -365.5499     0.9952898    704   12:18:25
#           LogLik        Sigma2     DF     wall
#  1     -360.9672     0.9824163    704   12:13:02

# %%
emp_p_partial = c()
perm_coef_avg = c()
perm_coef_se = c()
for(i in 1:5){
    tmp1 = colSums(testMLM_perm[[i]][,1:6]<rep(testMLM[i,1:6],nrow(testMLM_perm[[i]])))/nrow(testMLM_perm[[i]])
    tmp2 = colSums(testMLM_perm[[i]][,1:6]>rep(testMLM[i,1:6],nrow(testMLM_perm[[i]])))/nrow(testMLM_perm[[i]])
    emp_p_partial = rbind(emp_p_partial,apply(cbind(tmp1,tmp2),1,function(x) min(c(1,2*min(x)))))
    perm_coef_avg = rbind(perm_coef_avg,apply(testMLM_perm[[i]][,1:6],2,mean))
    perm_coef_se = rbind(perm_coef_se,apply(testMLM_perm[[i]][,1:6],2,function(x) sd(x)))
}

# %%
emp_p_partial2 = c()
perm_coef_avg2 = c()
perm_coef_se2 = c()
for(i in 1:5){
    tmp1 = colSums(testMLM_perm2[[i]][,1:6]<rep(testMLM2[i,1:6],nrow(testMLM_perm2[[i]])))/nrow(testMLM_perm2[[i]])
    tmp2 = colSums(testMLM_perm2[[i]][,1:6]>rep(testMLM2[i,1:6],nrow(testMLM_perm2[[i]])))/nrow(testMLM_perm2[[i]])
    emp_p_partial2 = rbind(emp_p_partial2,apply(cbind(tmp1,tmp2),1,function(x) min(c(1,2*min(x)))))
    perm_coef_avg2 = rbind(perm_coef_avg2,apply(testMLM_perm2[[i]][,1:6],2,mean))
    perm_coef_se2 = rbind(perm_coef_se2,apply(testMLM_perm2[[i]][,1:6],2,function(x) sd(x)))
}

# %%
emp_p_partial3 = c()
perm_coef_avg3 = c()
perm_coef_se3 = c()
for(i in 1:5){
    tmp1 = colSums(testMLM_perm3[[i]][,1:6]<rep(testMLM3[i,1:6],nrow(testMLM_perm3[[i]])))/nrow(testMLM_perm3[[i]])
    tmp2 = colSums(testMLM_perm3[[i]][,1:6]>rep(testMLM3[i,1:6],nrow(testMLM_perm3[[i]])))/nrow(testMLM_perm3[[i]])
    emp_p_partial3 = rbind(emp_p_partial3,apply(cbind(tmp1,tmp2),1,function(x) min(c(1,2*min(x)))))
    perm_coef_avg3 = rbind(perm_coef_avg3,apply(testMLM_perm3[[i]][,1:6],2,mean))
    perm_coef_se3 = rbind(perm_coef_se3,apply(testMLM_perm3[[i]][,1:6],2,function(x) sd(x)))
}

# %%
emp_p_partial4 = c()
perm_coef_avg4 = c()
perm_coef_se4 = c()
for(i in 1:5){
    tmp1 = colSums(testMLM_perm4[[i]][,1:6]<rep(testMLM4[i,1:6],nrow(testMLM_perm4[[i]])))/nrow(testMLM_perm4[[i]])
    tmp2 = colSums(testMLM_perm4[[i]][,1:6]>rep(testMLM4[i,1:6],nrow(testMLM_perm4[[i]])))/nrow(testMLM_perm4[[i]])
    emp_p_partial4 = rbind(emp_p_partial4,apply(cbind(tmp1,tmp2),1,function(x) min(c(1,2*min(x)))))
    perm_coef_avg4 = rbind(perm_coef_avg4,apply(testMLM_perm4[[i]][,1:6],2,mean))
    perm_coef_se4 = rbind(perm_coef_se4,apply(testMLM_perm4[[i]][,1:6],2,function(x) sd(x)))
}

# %%
emp_p_partial5 = c()
perm_coef_avg5 = c()
perm_coef_se5 = c()
for(i in 1:5){
    tmp1 = colSums(testMLM_perm5[[i]][,1:6]<rep(testMLM5[i,1:6],nrow(testMLM_perm5[[i]])))/nrow(testMLM_perm5[[i]])
    tmp2 = colSums(testMLM_perm5[[i]][,1:6]>rep(testMLM5[i,1:6],nrow(testMLM_perm5[[i]])))/nrow(testMLM_perm5[[i]])
    emp_p_partial5 = rbind(emp_p_partial5,apply(cbind(tmp1,tmp2),1,function(x) min(c(1,2*min(x)))))
    perm_coef_avg5 = rbind(perm_coef_avg5,apply(testMLM_perm5[[i]][,1:6],2,mean))
    perm_coef_se5 = rbind(perm_coef_se5,apply(testMLM_perm5[[i]][,1:6],2,function(x) sd(x)))
}

# %%
emp_p_partial2
testMLM2[1:5,7:12]
# Out:
#      Coeff_GRAVY Coeff_MW Coeff_Density Coeff_NC Coeff_Cost Coeff_GC
# [1,] 0.470       0.816    0.696         0.002    0.820      0.176
# [2,] 0.664       0.010    0.344         0.764    0.000      0.152
# [3,] 0.018       0.602    0.004         0.328    0.202      0.588
# [4,] 0.830       0.830    0.290         0.494    0.886      0.352
# [5,] 0.524       0.430    0.004         0.174    0.106      0.446
#         P_GRAVY   P_MW      P_Density   P_NC        P_Cost     P_GC
# envPC_1 0.9495578 0.8789356 0.357457238 0.003351173 0.66121334 0.1961788
# envPC_2 0.7370434 0.1512102 0.339729639 0.670515726 0.01509348 0.9486571
# envPC_3 0.1683074 0.2600193 0.003051713 0.971458323 0.10035191 0.2703806
# envPC_4 0.7013887 0.4920470 0.620080234 0.447784036 0.91320383 0.2315879
# envPC_5 0.6580840 0.9582215 0.177133821 0.273421104 0.41786458 0.3867708

# %%
emp_p_GLM = c()
emp_p_partial_GLM = c()
perm_coef_avg_GLM = c()
perm_coef_se_GLM = c()
for(i in 1:5){
#     hist(testMLM_perm[[i]]$LR)
#     abline(v = testMLM$LR[i],col = "red")
    emp_p_GLM = c(emp_p_GLM,sum(testGLM_perm[[i]]$LR>testGLM$LR[i])/nrow(testGLM_perm[[i]]))
    tmp1 = colSums(testGLM_perm[[i]][,5:8]<rep(testGLM[i,5:8],nrow(testGLM_perm[[i]])))/nrow(testGLM_perm[[i]])
    tmp2 = colSums(testGLM_perm[[i]][,5:8]>rep(testGLM[i,5:8],nrow(testGLM_perm[[i]])))/nrow(testGLM_perm[[i]])
    emp_p_partial_GLM = rbind(emp_p_partial_GLM,apply(cbind(tmp1,tmp2),1,function(x) min(c(1,2*min(x)))))
    perm_coef_avg_GLM = rbind(perm_coef_avg_GLM,apply(testGLM_perm[[i]][,5:8],2,mean))
    perm_coef_se_GLM = rbind(perm_coef_se_GLM,apply(testGLM_perm[[i]][,5:8],2,function(x) sd(x)))
}

# %%
emp_p_partial_GLM
# Out:
#      partialCoeff_aaPC1 partialCoeff_aaPC2 partialCoeff_aaPC3 partialCoeff_GC
# [1,] 0.324              0.094              0.440              0.074
# [2,] 0.408              0.672              0.644              0.624
# [3,] 0.284              0.692              0.940              0.692
# [4,] 0.492              0.914              0.954              0.978
# [5,] 0.136              0.800              0.648              0.818

# %%
png("/workdir/sh2246/p_phyloGWAS/output/figure/Fig4c_v5.png",width = 8.7*2.2,height = 8.7*1.25,units = "cm",
    res = 600,pointsize = 8)
options(repr.plot.width=10, repr.plot.height=10)
par(mfrow = c(5,1))
for(i in 1:5){
    par(mar = c(0,15,0,3))
    if(i==5) par(mar = c(4,15,.5,3))
    plotDF = rbind(testMLM[i,],testMLM3[i,],testMLM4[i,],testMLM5[i,])
    argName = rep(NA,6)
    sig = unlist(plotDF[,7:12])
#     sig2 = as.vector(rbind(emp_p_partial[i,],emp_p_partial3[i,],emp_p_partial4[i,],emp_p_partial5[i,]))
#     print(table(sig<.05,sig2<.05))
    seVec = as.vector(rbind(perm_coef_se[i,],perm_coef_se3[i,],perm_coef_se4[i,],perm_coef_se5[i,]))
    bp = barplot(as.matrix(plotDF[,1:6]),beside = T,las = 1,density = ifelse(sig<.05,100,0),horiz = F,
                 yaxt = 'n',angle = 45,ylim = c(-0.18,0.195),
                 col = alpha(c("royalblue","forestgreen","darkgoldenrod","grey"),.5),
                 border = c("royalblue","forestgreen","darkgoldenrod","grey"),
                 xlab = "",main = "",names.arg = argName,space = c(.2,1.5))
    sigLab = ifelse(sig<.05,'*','')
    sigLab[sig<.01] = "**"
    sigLab[sig<.005] = "***"
    labs = paste0(round(unlist(plotDF[,1:6]),2),sigLab)
    labs[sig> 0.05] = ""
    text(y = unlist(plotDF[,1:6])+ifelse(unlist(plotDF[,1:6])>0,1,-1)*seVec*c(1.6,2.05),x = unlist(bp),
         labels = labs,cex = 1.1)
    abline(h= 0)
    mtext(paste0("envPC",i,"\n",c("temperature","evaportranspiration","leaching potential",
                                  "flood potential","dry season")[[i]]),2,line = 1.5,las = 2,cex = 1.25)
    arrows(x0 = unlist(bp),x1 = unlist(bp),
           y0 = unlist(plotDF[,1:6])-seVec,
           y1 = unlist(plotDF[,1:6])+seVec,
           code = 3, angle = 90, length = .025, col = c("royalblue","forestgreen","darkgoldenrod","grey"))
    if (i ==5) mtext(c("Hydropathy (GRAVY)","Molecular Weight","Density","Nitrogen/Carbon","Cost","GC%"),
                     at = apply(bp,2,mean),1,line = 2,cex = 1.25)
    if (i == 1) legend("topright",bty = 'n', 
                       fill = alpha(c("royalblue","forestgreen","darkgoldenrod","grey"),.5),
                       border = c("royalblue","forestgreen","darkgoldenrod","grey"),
                       legend = c("all OGs","leaf abundant OGs","root abundant OGs","low-abundance OGs"),cex = 1.1)
}
dev.off()
# Out:
# pdf
#   2

# %%
cor(envDf[,c("envPC_1")],envDf[,"TN1_GSDE_5_quan50"],method = "spearman")
# Out:
# [1] -0.280285

# %%
tmp = envDf[,"TN1_GSDE_5_quan50"]/envDf[,"OC1_GSDE_5_quan50"]
tmp[tmp==Inf] = NA
cor(envDf[,c("envPC_1")],tmp,use = "complete")
# Out:
# [1] 0.009618925

# %%
png("/workdir/sh2246/p_phyloGWAS/output/figure/Fig4c_v3.png",width = 8.7*2,height = 8.7*1.5,units = "cm",
    res = 600,pointsize = 8)
par(mfrow = c(5,1))
for(i in 1:5){
    par(mar = c(0,5,0,3))
    plotDF = rbind(testGLM[i,5:8],perm_coef_avg_GLM[i,],testMLM[i,5:8],perm_coef_avg[i,])
    sig = rbind(emp_p_partial_GLM[i,],emp_p_partial[i,])
    argName = rep(NA,4)
    bp = barplot(as.matrix(plotDF),beside = T,las = 1,density = rep(c(100,0,100,0)),horiz = F,
            yaxt = 'n',angle = 45,ylim = c(-0.75,0.7),
            col = alpha(rep(c("orange","royalblue"),each = 2),.5),border = rep(c("orange","royalblue"),each = 2),
            xlab = "",main = "",names.arg = argName,space = c(.1,2))
    sigLab = ifelse(unlist(sig)<=.05,'*','')
    sigLab[unlist(sig)<=.01] = "**"
    sigLab[unlist(sig)<=.005] = "***"
    labs = paste(round(unlist(plotDF[c(1,3),]),2),sigLab)
    labs[unlist(sig)> 0.05] = ""
    text(y = unlist(plotDF[c(1,3),]),x = unlist(bp[c(1,3),]),
         labels = labs)
    arrows(x0 = unlist(bp[c(2,4),]),x1 = unlist(bp[c(2,4),]),
           y0 = unlist(plotDF[c(2,4),])-as.vector(rbind(perm_coef_se_GLM[i,],perm_coef_se[i,])),
           y1 = unlist(plotDF[c(2,4),])+as.vector(rbind(perm_coef_se_GLM[i,],perm_coef_se[i,])),
           code = 3, angle = 90, length = .05, col = c("orange","royalblue"))
    abline(h= 0)
    mtext(paste0("envPC",i),2,line = 3)
    if (i == 1) legend("topright",bty = 'n', fill = alpha(c("orange",NA,"royalblue",NA),.5),
                       border = c("orange","orange","royalblue","royalblue"),
                       legend = c("GLM","GLM_perm.","MLM","MLM_perm."))
}
dev.off()
# Out:
# pdf
#   2

# %%
png("/workdir/sh2246/p_phyloGWAS/output/figure/Fig4c_v4.png",width = 8.7*1.6,height = 8.7*1.2,units = "cm",
    res = 600,pointsize = 8)
par(mfrow = c(5,1))
for(i in 1:5){
    par(mar = c(0,3,0,3))
    plotDF = rbind(testGLM[i,5:8],testMLM[i,5:8])
    sig = rbind(emp_p_partial_GLM[i,],emp_p_partial[i,])
    argName = rep(NA,4)
    bp = barplot(as.matrix(plotDF),beside = T,las = 1,horiz = F,
            angle = 45,ylim = c(-1.2,1.2),xlim = c(1,17.5),
            col = alpha(c("orange","royalblue"),.5),border = c("orange","royalblue"),
            xlab = "",main = "",names.arg = argName,space = c(.1,2))
    sigLab = ifelse(unlist(sig)<=.05,'*','')
    sigLab[unlist(sig)<=.01] = "**"
    sigLab[unlist(sig)<=.005] = "***"
    labs = paste(round(unlist(plotDF),2),sigLab)
    labs[unlist(sig)> 0.05] = ""
    abline(h= 0)
    arrows(x0 = unlist(bp),x1 = unlist(bp),
           y0 = unlist(plotDF)-as.vector(rbind(perm_coef_se_GLM[i,],perm_coef_se[i,])),
           y1 = unlist(plotDF)+as.vector(rbind(perm_coef_se_GLM[i,],perm_coef_se[i,])),
           code = 3, angle = 90, length = .05, col = c("orange","royalblue"))
    text(y = unlist(plotDF),x = unlist(bp),offset = 1,
         labels = labs,pos = ifelse(unlist(plotDF)>0,3,1),cex = 1.5)
#     mtext(paste0("envPC",i),2,line = 3)
    if (i == 1) legend("topright",bty = 'n', fill = alpha(c("orange","royalblue"),.5),
                       border = c("orange","royalblue"),
                       legend = c("GLM","MLM"))
}
dev.off()
# Out:
# pdf
#   2

# %%
bp
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 2.5  6.6  10.7 14.8
# [2,] 3.6  7.7  11.8 15.9

# %%
png("/workdir/sh2246/p_phyloGWAS/output/figure/Fig4c_v4.png",width = 8.7*2,height = 8.7*1.5,units = "cm",
    res = 600,pointsize = 8)
par(mfrow = c(5,2))
for(i in 1:5){
    par(mar = c(.5,5,.5,0))
    sig = rbind(emp_p_partial_GLM[i,],emp_p_partial[i,])
    boxplot(testGLM_perm[[i]][,5:8],names = NA,ylim = c(-1,1),las = 2,ylab = paste0("envPC",i),
            col = NA,border = "orange",xaxt = 'n')
    points(1:4,testGLM[i,5:8],pch = 17,cex = 2,col = "orange")
    par(mar = c(.5,3,.5,2))
    boxplot(testMLM_perm[[i]][,5:8],names = NA,ylim = c(-.3,.3),las = 2,
            col = NA,border = "royalblue",xaxt = 'n')
    points(1:4,testMLM[i,5:8],pch = 17,cex = 2,col = "royalblue")
}
dev.off()
# Out:
# pdf
#   2

# %%
# png("/workdir/sh2246/p_phyloGWAS/output/figure/Fig4c_v4.png",width = 8.7*1.5,height = 8.7*1.5,units = "cm",
#     res = 600,pointsize = 8)
par(mfrow = c(5,1))
for(i in 1:5){
    par(mar = c(0,5,0,3))
    sig = rbind(emp_p_partial_GLM[i,],emp_p_partial[i,])
    boxplot(testGLM_perm[[i]][,5:8],at = (1:4)-.25,boxwex = .4,
            names = NA,ylim = c(-1,1),las = 2,ylab = paste0("envPC",i),xlim = c(.5,4.5),
            border = "orange",col = NA)
    boxplot(testMLM_perm[[i]][,5:8],at = (1:4) +.25,boxwex = .4,
            names = NA,ylim = c(-.3,.3),yaxt = 'n',add = T,xlim = c(.5,4.5),
            border = "royalblue",col = NA)
    points((1:4)-.25,testGLM[i,5:8],pch = 17,cex = 3,col = "orange")
    points((1:4)+.25,testMLM[i,5:8],pch = 17,cex = 3,col = "royalblue")
    abline(h = 0,lty = 2)
}
# dev.off()
# Out:
# plot without title

# %%
unlist(testGLM_perm[[i]][,5:8])
# Out:
#    partialCoeff_aaPC11    partialCoeff_aaPC12    partialCoeff_aaPC13
#          -2.166189e-02          -1.634492e-01          -8.539117e-02
#    partialCoeff_aaPC14    partialCoeff_aaPC15    partialCoeff_aaPC16
#          -2.862474e-02           9.433655e-02           1.009912e-01
#    partialCoeff_aaPC17    partialCoeff_aaPC18    partialCoeff_aaPC19
#          -7.961188e-02           2.381937e-02           6.758126e-02
#   partialCoeff_aaPC110   partialCoeff_aaPC111   partialCoeff_aaPC112
#          -7.628952e-02          -3.630517e-02          -4.225575e-02
#   partialCoeff_aaPC113   partialCoeff_aaPC114   partialCoeff_aaPC115
#          -3.165783e-02           1.317795e-01          -6.879310e-02
#   partialCoeff_aaPC116   partialCoeff_aaPC117   partialCoeff_aaPC118
#           5.553034e-02           8.537030e-02          -4.871592e-02
#   partialCoeff_aaPC119   partialCoeff_aaPC120   partialCoeff_aaPC121
#          -4.239907e-02          -7.078782e-02          -8.461201e-02
# ...

# %%
as.vector(rbind(perm_coef_se_GLM[i,],perm_coef_se[i,]))
# Out:
# [1] 0.06461275 0.02854868 0.36540016 0.06925527 0.28394818 0.05576492 0.35030496
# [8] 0.08485680

# %%
unlist(plotDF[c(2,4),])
# Out:
# partialCoeff_aaPC11 partialCoeff_aaPC12 partialCoeff_aaPC21 partialCoeff_aaPC22
#        -0.004286163        -0.001954463        -0.043981268         0.015922773
# partialCoeff_aaPC31 partialCoeff_aaPC32    partialCoeff_GC1    partialCoeff_GC2
#         0.019183936        -0.010438087         0.072839873        -0.010128867

# %%
?barplot

# %%
i
# Out:
# [1] 5

# %%
png("/workdir/sh2246/p_phyloGWAS/output/figure/Fig4c_S1.png",width = 8.7*2.3,height = 8.7*1,units = "cm",
    res = 600,pointsize = 8)
par(mfrow = c(1,5))
for(i in 1:5){
    par(mar = c(5,1,3,1))
    plotDF = rbind(testGLM_andro[i,],testMLM_andro[i,])
    bp = barplot(as.matrix(plotDF[,8:5]),beside = T,las = 1,density = ifelse(plotDF[,12:9]<.05,100,0),horiz = T,
            yaxt = 'n',angle = 45,xlim = c(-1,1.2),
            col = alpha(c("orange","royalblue"),.5),border = c("orange","royalblue"),
            xlab = paste(sprintf("%.2e", plotDF[,4]),collapse = "\n"),main = paste0("envPC",i))
    sigLab = ifelse(unlist(plotDF[,12:9])<.05,'*','')
    sigLab[unlist(plotDF[,12:9])<.01] = "**"
    sigLab[unlist(plotDF[,12:9])<.005] = "***"
    text(x = unlist(plotDF[,8:5]),y = unlist(bp),
         labels = sigLab)
    abline(v= 0)
    if (i == 5) legend("topright",bty = 'n', fill = alpha(c("orange","royalblue"),.5),
                       border = c("orange","royalblue"),legend = c("GLM","MLM"))
}
dev.off()
# Out:
# pdf
#   2

# %%
names(mycol) = levels(as.factor(dat1$tribe))

# %%
names(mycol)
# Out:
#  [1] "Andropogoneae"   "Arundinarieae"   "Bambuseae"       "Brachypodieae"
#  [5] "Bromeae"         "Cynodonteae"     "Eragrostideae"   "Molinieae"
#  [9] "Olyreae"         "Oryzeae"         "Paniceae"        "Paspaleae"
# [13] "Phareae"         "Poeae"           "Stipeae"         "Streptochaeteae"
# [17] "Triraphideae"    "Triticeae"       "Zoysieae"        NA
# [21] NA                NA                NA                NA
# [25] NA

# %%
plot(dat1$GC,dat1$envPC_3,col = mycol[as.factor(dat1$tribe)])
for(i in na.omit(names(mycol))){
    if(sum(dat1$tribe%in%i)<20) next
    fm_andro = with(dat1[dat1$tribe%in%i,],lm(envPC_3~GC))
    abline(a = fm_andro$coefficients[1],b= fm_andro$coefficients[2],col = mycol[i],lwd = 2)
}
legend("topright",lty = 1, col = mycol[names(which(table(dat1$tribe)>=20))],
       legend = names(which(table(dat1$tribe)>=20)))
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height=8)
pheatmap(-log10(test[,c(4,12:18)]),cluster_rows = F,cluster_cols = F)
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height=8)
pheatmap(-log10(test[,c(4,12:18)]),cluster_rows = F,cluster_cols = F)
# Out:
# plot without title

# %%
test
# Out:
#                                               BIC_full  BIC_reduced LR
# envPC_1                                        165.0637  159.1584   42.243404
# envPC_2                                        410.8060  394.3742   31.716963
# envPC_3                                        460.9993  437.5316   24.681030
# envPC_4                                        472.6293  433.3595    8.878897
# envPC_5                                        481.0972  439.5892    6.640719
# envPC_6                                        340.4682  326.6600   34.340542
# envPC_7                                        392.8094  351.2842    6.623531
# envPC_8                                        372.5913  351.6246   27.182041
# envPC_9                                        292.7119  275.5039   30.940736
# envPC_10                                       508.8436  493.9435   33.248743
# TN1_GSDE_5_quan50                             1804.1817 1792.6160   36.583073
# ...

# %%
options(repr.plot.width=8, repr.plot.height=8)
pheatmap(-log10(test[,c(4,13:20)]),cluster_rows = F,cluster_cols = F)
# Out:
# plot without title

# %%
test_glm = mclapply(c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50"),
                function(x) fit_model_glm(dat1,phyloKMat,x),mc.cores = 13)

test_glm = t(simplify2array(test_glm))
test_glm = as.data.frame(test_glm)
rownames(test_glm) = c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50")
# Out:
# ASReml Version 4.2 12/07/2025 13:52:20
#           LogLik        Sigma2     DF     wall
#  1     -3972.144      28491.06    703   13:52:20
#           LogLik        Sigma2     DF     wall
#  1     -368.0667      1.003933    703   13:52:19

# %%
test_glm
# Out:
#                                               BIC_full  BIC_reduced LR
# envPC_1                                        645.2200  689.9253    84.062991
# envPC_2                                        763.3675  743.6191    19.609265
# envPC_3                                        758.1386  747.6307    28.849791
# envPC_4                                        773.0296  748.8034    15.131427
# envPC_5                                        750.7842  732.0099    20.583428
# envPC_6                                        748.9384  738.9149    29.334152
# envPC_7                                        762.8470  737.5928    14.103487
# envPC_8                                        697.2915  721.7476    63.813731
# envPC_9                                        785.1512  757.9013    12.107771
# envPC_10                                       767.8471  738.5528    10.063433
# TN1_GSDE_5_quan50                             2946.7137 2934.6369    27.280955
# ...

# %%
with(dat1, anova(lm(envPC_1 ~ aaPC1 + aaPC2 + aaPC3 + NperAA + GC + NperDNA + asmGC + locoGSE1Cx + asmSize + compdup)))
# Out:
#            Df  Sum Sq       Mean Sq      F value    Pr(>F)
# aaPC1        1 1.563198e+01 15.631975286 30.3832023 6.367490e-08
# aaPC2        1 6.482537e+00  6.482536866 12.5998298 4.316394e-04
# aaPC3        1 8.833958e-01  0.883395784  1.7170186 1.908292e-01
# NperAA       1 3.603149e+00  3.603149402  7.0032875 8.457111e-03
# GC           1 5.057104e+00  5.057103691  9.8292763 1.844341e-03
# NperDNA      1 6.706447e+00  6.706446568 13.0350336 3.445566e-04
# asmGC        1 4.489796e+00  4.489795755  8.7266241 3.321217e-03
# locoGSE1Cx   1 3.893742e-01  0.389374247  0.7568101 3.848504e-01
# asmSize      1 9.663762e-02  0.096637621  0.1878304 6.649621e-01
# compdup      1 3.831437e-03  0.003831437  0.0074470 9.312743e-01
# Residuals  400 2.057976e+02  0.514494001         NA           NA

# %%
with(dat1,plot(envPC_1,locoGSE1Cx))
# Out:
# plot without title

# %%
with(dat1,cor(envPC_1,locoGSE1Cx,use = "pairwise.complete")^2)
# Out:
# [1] 0.006353194

# %%
with(dat1, anova(lm(envPC_1 ~ aaPC1 + aaPC2 + aaPC3 + NperAA + GC + NperDNA + asmGC + asmSize + compdup + pacbio)))
# Out:
#           Df  Sum Sq       Mean Sq      F value      Pr(>F)
# aaPC1       1 3.593607e-02 3.593607e-02 4.830281e-02 8.261078e-01
# aaPC2       1 1.129356e+01 1.129356e+01 1.518003e+01 1.071786e-04
# aaPC3       1 5.667117e-04 5.667117e-04 7.617353e-04 9.779895e-01
# NperAA      1 3.168868e+01 3.168868e+01 4.259377e+01 1.299043e-10
# GC          1 3.616658e+01 3.616658e+01 4.861266e+01 7.266301e-12
# NperDNA     1 1.098174e+01 1.098174e+01 1.476090e+01 1.332075e-04
# asmGC       1 3.518213e+00 3.518213e+00 4.728942e+00 2.999570e-02
# asmSize     1 3.991269e+01 3.991269e+01 5.364792e+01 6.663015e-13
# compdup     1 4.427865e-01 4.427865e-01 5.951634e-01 4.406916e-01
# pacbio      1 2.781783e+01 2.781783e+01 3.739084e+01 1.612295e-09
# Residuals 695 5.170624e+02 7.439746e-01           NA           NA

# %%
test2 = mclapply(c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50"),
                function(x) fit_model(dat2,phyloKMat,x),mc.cores = 5)

# %%
test2 = t(simplify2array(test2))
test2 = as.data.frame(test2)
rownames(test2) = c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50")

# %%
test2
# Out:
#                                               BIC_full  BIC_reduced LR
# envPC_1                                        243.5863  225.6474   1.73995631
# envPC_2                                        514.3903  499.7407   5.02921651
# envPC_3                                        663.0745  648.1468   4.75121614
# envPC_4                                        691.0334  672.7134   1.35889364
# envPC_5                                        587.0891  574.3605   6.95021957
# envPC_6                                        576.3800  556.7311   0.02991007
# envPC_7                                        725.4610  708.9072   3.12499891
# envPC_8                                        474.7981  458.1568   3.03749929
# envPC_9                                        687.9855  671.0934   2.78676886
# envPC_10                                       749.9968  732.7426   2.42456864
# TN1_GSDE_5_quan50                             2872.8747 2860.7120   7.51615292
# ...

# %%
test3 = mclapply(c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50"),
                function(x) fit_model_aa(dat3,phyloKMat,x),mc.cores = 5)

# %%
test3[[1]]
# Out:
#    BIC_full BIC_reduced          LR           p
# 303.1752323 192.7735026  14.8921261   0.7825465

# %%
test3 = t(simplify2array(test3))
test3 = as.data.frame(test3)
rownames(test3) = c(paste("envPC",1:10,sep = "_"),"TN1_GSDE_5_quan50","TC1_GSDE_5_quan50","bio08_Mean_Temperature_Wettest_Quarter_quan50")

# %%
options(repr.plot.width=8, repr.plot.height=8)
plot(-log10(test[,4]),-log10(test2[,4]),xlab = "all OGs",ylab = "photosynthetic OGs",type = 'n',xaxt = "n",yaxt= "n")
axis(1,at = seq(0,2,0.5),labels = round(10^(-seq(0,2,0.5)),3))
axis(2,at = seq(0,2,0.5),labels = round(10^(-seq(0,2,0.5)),3))
abline(a= 0,b= 1,col = "blue",lty =2)
text(-log10(test[,4]),-log10(test2[,4]),labels = c(paste0("envPC",1:10),"TN","TC","Bio08"))
cor.test(-log10(test[,4]),-log10(test2[,4]))
# Out:
# 	Pearson's product-moment correlation
#
# data:  -log10(test[, 4]) and -log10(test2[, 4])
# t = 0.73266, df = 11, p-value = 0.4791
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.3805041  0.6852478
# sample estimates:
#      cor
# 0.215704
# plot without title

# %%
grep("envPC",colnames(dat1))
# Out:
#  [1] 287 288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305
# [20] 306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323 324
# [39] 325 326

# %%
for(i in 287:296){
    print(cor(dat1$TN1_GSDE_5_quan50,dat1[,i],method = "spearman"))
}
# Out:
# [1] -0.2849802
# [1] -0.5561781
# [1] 0.08273271
# [1] 0.1472828
# [1] -0.01589609
# [1] -0.09617431
# [1] 0.3562907
# [1] 0.2388204
# [1] 0.3430943
# [1] 0.03108774

# %%
with(dat1,lm(TN1_GSDE_5_quan50~envPC_1+envPC_2+envPC_3+envPC_4+envPC_5+envPC_6+envPC_7+envPC_8+envPC_9+envPC_10))
# Out:
# Call:
# lm(formula = TN1_GSDE_5_quan50 ~ envPC_1 + envPC_2 + envPC_3 +
#     envPC_4 + envPC_5 + envPC_6 + envPC_7 + envPC_8 + envPC_9 +
#     envPC_10)
#
# Coefficients:
# (Intercept)      envPC_1      envPC_2      envPC_3      envPC_4      envPC_5
#     13.2029      -0.8308      -2.1469       0.8414       0.5115       0.1341
#     envPC_6      envPC_7      envPC_8      envPC_9     envPC_10
#     -0.2329       1.1751       1.6769       1.9900       0.5367

# %%
plot(dat1$TN1_GSDE_5_quan50,dat1$envPC_2)
plot(dat1$TN1_GSDE_5_quan50,dat1$envPC_8)
plot(dat1$TN1_GSDE_5_quan50,dat1$envPC_9)
# Out:
# plot without title
# plot without title
# plot without title

# %%
cor(dat2$bio08_Mean_Temperature_Wettest_Quarter_quan50,dat2$envPC_1)
cor(dat2$bio08_Mean_Temperature_Wettest_Quarter_quan50,dat2$envPC_2)
cor(dat2$bio08_Mean_Temperature_Wettest_Quarter_quan50,dat2$envPC_3)
cor(dat2$bio08_Mean_Temperature_Wettest_Quarter_quan50,dat2$envPC_4)
cor(dat2$bio08_Mean_Temperature_Wettest_Quarter_quan50,dat2$envPC_5)
cor(dat2$bio08_Mean_Temperature_Wettest_Quarter_quan50,dat2$envPC_6)
cor(dat2$bio08_Mean_Temperature_Wettest_Quarter_quan50,dat2$envPC_7)
cor(dat2$bio08_Mean_Temperature_Wettest_Quarter_quan50,dat2$envPC_8)
cor(dat2$bio08_Mean_Temperature_Wettest_Quarter_quan50,dat2$envPC_9)
cor(dat2$bio08_Mean_Temperature_Wettest_Quarter_quan50,dat2$envPC_10)
plot(dat2$bio08_Mean_Temperature_Wettest_Quarter_quan50,dat2$envPC_1,xlab = "Bio08",ylab = "envPC1")
# Out:
# [1] 0.7569664
# [1] -0.05179215
# [1] -0.2310727
# [1] -0.1011625
# [1] 0.2845143
# [1] 0.1398712
# [1] 0.07699443
# [1] 0.3363904
# [1] -0.08382677
# [1] -0.01414988
# plot without title

# %%
fit_model_N <- function(data, Kmat,responseVar) {
#   library(asreml)
    gc()
    asreml.options(verbose = FALSE)
    tmp = data
    fullFM = as.formula(paste0(responseVar, "~ NperAA + compdup + pacbio"))
    reducedFM = as.formula(paste0(responseVar, "~ compdup + pacbio"))

    model_full <- asreml(fixed = fullFM,
                         random = ~ vm(assemblyID, Kmat) , ai.sing = F, data = data)
#     model_reduced1 <- asreml(fixed = fullFM,
#                              ai.sing = F, data = data)
    data <- tmp
    model_reduced2 <- asreml(fixed = reducedFM,
                             random = ~ vm(assemblyID, Kmat) , ai.sing = F, data = data)  
    
    totalVar = var(data[,responseVar])
    modelSummary <- summary(model_full)
    IC_full = infoCriteria(model_full,IClikelihood = "full")
    IC_reduced = infoCriteria(model_reduced2,IClikelihood = "full")
    logLik_full <- IC_full$loglik
    logLik_reduced <- IC_reduced$loglik
    BIC_full <- IC_full$BIC
    BIC_reduced <- IC_reduced$BIC

    LRT_statistic <- -2 * (logLik_reduced - logLik_full)
    p_value <- pchisq(LRT_statistic, df = 1, lower.tail = FALSE)
#     gene_explained <-  (model_reduced2$sigma2-model_full$sigma2)/totalVar
#     phylo_explained <- (model_reduced1$sigma2-model_full$sigma2)/totalVar
  
    modelWald <- wald.asreml(model_full)
    partialCoeff <- model_full$coefficients$fixed[2]
    partialPval <- modelWald[2,4]

#     return(model_full)
    out = c(BIC_full,BIC_reduced,LRT_statistic,p_value,partialCoeff,partialPval)
    names(out) = c("BIC_full","BIC_reduced","LR","p",
                   paste("partialCoeff",c("NperAA"),sep = "_"),
                   paste("partialP",c("NperAA"),sep = "_"))
    if(model_full$converge) return(out)
    else return(NULL)
}

# %%
plot(dat$PC1,dat$NperAA)
cor.test(dat$PC1,dat$NperAA,method = "spearman")
# Out:
# Warning message in cor.test.default(dat$PC1, dat$NperAA, method = "spearman"):
# “Cannot compute exact p-value with ties”
# 	Spearman's rank correlation rho
#
# data:  dat$PC1 and dat$NperAA
# S = 15232184, p-value < 2.2e-16
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.7909795
# plot without title

# %%
fit_model_N(dat,phyloKMat,'TN1_GSDE_5_quan50')
# Out:
# ASReml Version 4.2 18/02/2025 15:45:43
#           LogLik        Sigma2     DF     wall
#  1     -1539.613      20.12613    755   15:45:43
#  2     -1533.639      19.49397    755   15:45:43
#  3     -1526.751      18.58867    755   15:45:43
#  4     -1522.205      17.68310    755   15:45:44
#  5     -1520.449      16.94531    755   15:45:44
#  6     -1520.275      16.68247    755   15:45:44
#  7     -1520.270      16.63368    755   15:45:44
# ASReml Version 4.2 18/02/2025 15:45:44
#           LogLik        Sigma2     DF     wall
#  1     -1543.179      20.12875    756   15:45:44
#  2     -1537.226      19.49824    756   15:45:44
#  3     -1530.342      18.59328    756   15:45:45
#  4     -1525.777      17.68534    756   15:45:45
#  5     -1523.999      16.94296    756   15:45:45
#  6     -1523.818      16.67594    756   15:45:45
#  7     -1523.813      16.62540    756   15:45:45
#            BIC_full         BIC_reduced                  LR                   p
# ...

# %%
dat[dat$assemblyID%in%names(which(PCA.aa.comp$x[,1]>0.01)),]

# %%
library(geiger)
# load tree
spTre = read.tree("/workdir/sh2246/p_phyloGWAS/output/PoaceaeTree_angiosperm353_astral_filtered_withEnvData_20250416.nwk")
spTre.rooted = root(spTre,"ASM1935983v1")
spTre.rooted$edge.length[is.na(spTre.rooted$edge.length)] = 0.1 # to fill tip branch length
spTre.rooted.resolved = ape::multi2di(spTre.rooted)

# trait vector
trait_test = dat1$envPC_1
names(trait_test) = rownames(dat1)

# rate estimates and simulation
rate_test = ratematrix(spTre.rooted.resolved, trait_test)
trait_sim = sim.char(spTre.rooted.resolved,rate_test,nsim = 1)

# check variance-covariance matrices
vcv_test = vcv(spTre.rooted.resolved, trait_test)
vcv_sim = vcv(spTre.rooted.resolved, trait_sim)

pheatmap(vcv_test,cluster_rows = F,cluster_cols = F,show_rownames = F,show_colnames = F)
pheatmap(vcv_sim,cluster_rows = F,cluster_cols = F,show_rownames = F,show_colnames = F)
# Out:
# plot without title
# plot without title

# %%
# rate estimates and simulation
rate_test = ratematrix(spTre.rooted.resolved, trait_test)
# vcv_test = vcv(spTre.rooted.resolved, trait_test)
# pheatmap(vcv_test,cluster_rows = F,cluster_cols = F,show_rownames = F,show_colnames = F)
trait_sim = sim.char(spTre.rooted.resolved,rate_test,nsim = 100)
trait_permulated = trait_test[order(trait_sim[,,1])]

# %%
options(repr.plot.width=8, repr.plot.height=8)
plot(trait_test,trait_permulated,xlab = "envPC1",ylab = "simulated trait")
# Out:
# plot without title

# %%
cor(trait_test,trait_permulated,method = "spearman")
# Out:
# [1] 0.123181

# %%
vcv_test = vcv(spTre.rooted.resolved, trait_test)
vcv_sim = vcv(spTre.rooted.resolved, trait_sim)

pheatmap(vcv_test,cluster_rows = F,cluster_cols = F,show_rownames = F,show_colnames = F)
pheatmap(vcv_sim,cluster_rows = F,cluster_cols = F,show_rownames = F,show_colnames = F)
# Out:
# plot without title
# plot without title

# %%
names(trait_sim) = names(trait_test)

rateSim = c()
for(i in 1:100){
    rateSim = c(rateSim,ratematrix(spTre.rooted.resolved, trait_sim[,1,i]))
}

hist(rateSim,main = "",xlab = "trait evolutionary rate")
abline(v = rate_test, col = "red")
# Out:
# Plot with title “”

# %%
?ratematrix

# %%
# spTre = read.tree("/workdir/sh2246/p_phyloGWAS/output/PoaceaeTree_angiosperm353_astral_filtered_20250407.nwk")
# spTre = keep.tip(spTre,rownames(envDf))
# spTre.rooted = root(spTre,"ASM1935983v1")
# spTre.rooted$edge.length[is.na(spTre.rooted$edge.length)] = 0.1 # to fill tip branch length

spTre.rooted.resolved = ape::multi2di(spTre.rooted)

#permulate life history
set.seed(123)
# trait vector
trait_test = metadata$lifeHistory
names(trait_test) = rownames(metadata)
trait_test = na.omit(trait_test[!trait_test%in%"annual or perennial"])
trait_test2 = as.numeric(trait_test=="perennial")
names(trait_test2) = names(trait_test)
spTre.rooted.resolved = keep.tip(spTre.rooted.resolved,names(trait_test2))
# rate estimates and simulation
rate_test = ratematrix(spTre.rooted.resolved, trait_test2)
trait_sim = sim.char(spTre.rooted.resolved,rate_test,nsim = 1)
trait_permulated = trait_test2[order(trait_sim[,,1])]

# %%
names(trait_permulated) = names(trait_test2)

# %%
mcnemar.test(table(trait_permulated,trait_test2))
# Out:
# 	McNemar's Chi-squared test
#
# data:  table(trait_permulated, trait_test2)
# McNemar's chi-squared = 0, df = 1, p-value = 1

# %%
outDf = data.frame("assemblyID" = names(trait_permulated),"perm_lifeHistory" = trait_permulated)

# %%
fwrite(outDf,"/workdir/sh2246/p_phyloGWAS/output/permulatedLifeHistory_20250818.txt",sep = "\t",row.name = F)
